# %% [markdown]
# <a href="https://colab.research.google.com/github/Ali-Ahmed-xixa/301-redirect-url-CSV-mapper-paython/blob/main/shopware%20to%20jtl%20migration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
from datetime import datetime

def map_shopware_to_jtl(shopware_file, output_file):
    # JTL headers in correct order
    jtl_headers = [
        'kKundengruppe', 'kSprache', 'cKundenNr', 'cPasswort',
        'cAnrede', 'cTitel', 'cVorname', 'cNachname', 'cFirma', 'cZusatz',
        'cStrasse', 'cHausnummer', 'cAdressZusatz', 'cPLZ', 'cOrt',
        'cBundesland', 'cLand', 'cTel', 'cMobil', 'cFax', 'cMail', 'cUSTID',
        'cWWW', 'cSperre', 'fGuthaben', 'cNewsletter', 'dGeburtstag',
        'fRabatt', 'cHerkunft', 'dErstellt', 'dVeraendert', 'cAktiv',
        'cAbgeholt', 'nRegistriert', 'nLoginversuche', 'dLastLogin',
        'dSessionInvalidate', 'b2FAauth', 'c2FAauthSecret'
    ]

    # Explicit field mapping with transformations
    field_mapping = {
        'customernumber': ('cKundenNr', str),
        'email': ('cMail', str),
        'password': ('cPasswort', str),
        'active': ('cAktiv', lambda x: 'Y' if str(x) == '1' else 'N'),
        'billing_company': ('cFirma', str),
        'billing_department': ('cZusatz', str),
        'billing_salutation': ('cAnrede', lambda x: 'Herr' if str(x).lower() == 'mr' else 'Frau' if str(x).lower() == 'ms' else str(x)),
        'billing_firstname': ('cVorname', str),
        'billing_lastname': ('cNachname', str),
        'billing_street': ('cStrasse', str),
        'billing_zipcode': ('cPLZ', str),
        'billing_city': ('cOrt', str),
        'phone': ('cTel', str),
        'fax': ('cFax', str),
        'ustid': ('cUSTID', str),
        'newsletter': ('cNewsletter', lambda x: '1' if str(x) == '1' else '0'),
        'customergroup': ('kKundengruppe', str),
        'language': ('kSprache', str)
    }

    with open(shopware_file, mode='r', encoding='utf-8') as infile, \
         open(output_file, mode='w', encoding='utf-8', newline='') as outfile:

        # Read first line to detect delimiter
        first_line = infile.readline()
        delimiter = '\t' if '\t' in first_line else ','
        infile.seek(0)

        # Read Shopware CSV
        reader = csv.DictReader(infile, delimiter=delimiter)
        print(f"Detected Shopware headers: {reader.fieldnames}")

        # Verify required fields exist
        missing_fields = [f for f in field_mapping if f not in reader.fieldnames]
        if missing_fields:
            raise ValueError(f"Missing required fields in Shopware CSV: {missing_fields}")

        # Write JTL CSV
        writer = csv.DictWriter(outfile, fieldnames=jtl_headers, delimiter=';')
        writer.writeheader()

        for idx, row in enumerate(reader, start=1):
            jtl_row = {h: '' for h in jtl_headers}

            # Set automatic fields
            jtl_row['dErstellt'] = datetime.now().strftime('%Y-%m-%d')
            jtl_row['dVeraendert'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
            jtl_row['cSperre'] = 'N'
            jtl_row['fGuthaben'] = '0.00'
            jtl_row['fRabatt'] = '0.00'
            jtl_row['nRegistriert'] = '0'

            # Map all fields
            for shopware_field, (jtl_field, transform) in field_mapping.items():
                if shopware_field in row:
                    try:
                        value = row[shopware_field].strip() if row[shopware_field] else ''
                        if value:
                            jtl_row[jtl_field] = transform(value)
                    except Exception as e:
                        print(f"Error transforming {shopware_field}: {e}")
                        jtl_row[jtl_field] = ''

            # Handle street/house number
            if jtl_row['cStrasse']:
                street = jtl_row['cStrasse']
                parts = street.rsplit(' ', 1)
                if len(parts) > 1 and parts[1][0].isdigit():
                    jtl_row['cStrasse'] = parts[0]
                    jtl_row['cHausnummer'] = parts[1]

            writer.writerow(jtl_row)

            # Print first row for verification
            if idx == 1:
                print("\nFirst converted row:")
                for k, v in jtl_row.items():
                    if v: print(f"{k}: {v}")

    print(f"\nSuccessfully converted {idx} records to {output_file}")

if __name__ == "__main__":
    map_shopware_to_jtl(
        shopware_file='s_user_new.csv',
        output_file='jtl_export_7_01_2025.csv'
    )
# Out:
# Detected Shopware headers: ['id', 'password', 'encoder', 'email', 'active', 'accountmode', 'confirmationkey', 'paymentID', 'doubleOptinRegister', 'doubleOptinEmailSentDate', 'doubleOptinConfirmDate', 'firstlogin', 'lastlogin', 'sessionID', 'newsletter', 'validation', 'affiliate', 'customergroup', 'paymentpreset', 'language', 'subshopID', 'referer', 'pricegroupID', 'internalcomment', 'failedlogins', 'lockeduntil', 'default_billing_address_id', 'default_shipping_address_id', 'title', 'salutation', 'firstname', 'lastname', 'birthday', 'customernumber', 'login_token', 'changed', 'password_change_date', 'register_opt_in_id']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-17-1684712492.py in <cell line: 0>()
#      99
#     100 if __name__ == "__main__":
# --> 101     map_shopware_to_jtl(
#     102         shopware_file='s_user_new.csv',
#     103         output_file='jtl_export_7_01_2025.csv'
#
# /tmp/ipython-input-17-1684712492.py in map_shopware_to_jtl(shopware_file, output_file)
#      52         missing_fields = [f for f in field_mapping if f not in reader.fieldnames]
#      53         if missing_fields:
# ---> 54             raise ValueError(f"Missing required fields in Shopware CSV: {missing_fields}")
#      55
#      56         # Write JTL CSV
#
# ValueError: Missing required fields in Shopware CSV: ['billing_company', 'billing_department', 'billing_salutation', 'billing_firstname', 'billing_lastname', 'billing_street', 'billing_zipcode', 'billing_city', 'phone', 'fax', 'ustid']

# %%
import csv
from datetime import datetime

def convert_shopware_to_jtl(shopware_csv_path, jtl_csv_path):
    # Define JTL Shop 5 header
    jtl_header = [
        'kBestellung', 'kWarenkorb', 'kKunde', 'kLieferadresse', 'kRechnungsadresse',
        'kZahlungsart', 'kVersandart', 'kSprache', 'kWaehrung', 'fGuthaben', 'fGesamtsumme',
        'cSession', 'cVersandartName', 'cZahlungsartName', 'cBestellNr', 'cVersandInfo',
        'nLongestMinDelivery', 'nLongestMaxDelivery', 'dVersandDatum', 'dBezahltDatum',
        'dBewertungErinnerung', 'cTracking', 'cKommentar', 'cLogistiker', 'cTrackingURL',
        'cIP', 'cAbgeholt', 'cStatus', 'dErstellt', 'fWaehrungsFaktor', 'cPUIZahlungsdaten'
    ]

    def get_safe_value(row, key, default=''):
        """Safely get value from row with case-insensitive key matching"""
        for k, v in row.items():
            if k.lower() == key.lower():
                return v
        return default

    def transform_order(shopware_order):
        # Status mapping (Shopware → JTL)
        status_map = {
            '0': '0',   # Open
            '1': '1',   # In process
            '2': '2',   # Completed
            '3': '3',   # Partially completed
            '4': '4',   # Cancelled
            '5': '5',   # Ready for shipping
            '6': '6',   # Partially shipped
            '7': '2',   # Completed (from your example)
            '12': '2'   # Completed (Shopware cleared status)
        }

        # Payment method names
        payment_names = {
            '3': 'Vorkasse',
            '5': 'Nachnahme',
            '7': 'Überweisung'
        }

        # Shipping method names
        shipping_names = {
            '3': 'DHL',
            '9': 'Standard'
        }


        return {
            'kBestellung': get_safe_value(shopware_order, 'id'),
            'kWarenkorb': '3',
            'kKunde': get_safe_value(shopware_order, 'userID'),
            'kLieferadresse': '0',
            'kRechnungsadresse': '3',
            'kZahlungsart': get_safe_value(shopware_order, 'paymentID'),
            'kVersandart': get_safe_value(shopware_order, 'dispatchID'),
            'kSprache': '1' if get_safe_value(shopware_order, 'language') == '1' else '7',
            'kWaehrung': '1' if get_safe_value(shopware_order, 'currency') == 'EUR' else '2',
            'fGuthaben': '0',
            'fGesamtsumme': get_safe_value(shopware_order, 'invoice_amount'),
            'cSession': '9sk7f2fprla53cj37nn6okhhac',
            'cVersandartName': shipping_names.get(get_safe_value(shopware_order, 'dispatchID'), 'Standard'),
            'cZahlungsartName': payment_names.get(get_safe_value(shopware_order, 'paymentID'), 'Überweisung'),
            'cBestellNr': get_safe_value(shopware_order, 'ordernumber'),
            'cVersandInfo': get_safe_value(shopware_order, 'trackingcode'),
            'nLongestMinDelivery': '2',
            'nLongestMaxDelivery': '3',
            'dVersandDatum': '',
            'dBezahltDatum': get_safe_value(shopware_order, 'cleareddate').split()[0] if get_safe_value(shopware_order, 'cleareddate') else '',
            'dBewertungErinnerung': 'NULL',
            'cTracking': get_safe_value(shopware_order, 'trackingcode'),
            'cKommentar': get_safe_value(shopware_order, 'comment', 'NULL'),
            'cLogistiker': '',
            'cTrackingURL': '',
            'cIP': get_safe_value(shopware_order, 'remote_addr'),
            'cAbgeholt': 'Y',
            'cStatus': status_map.get(get_safe_value(shopware_order, 'status', '0'), '0'),
            'dErstellt': get_safe_value(shopware_order, 'ordertime'),
            'fWaehrungsFaktor': get_safe_value(shopware_order, 'currencyFactor', '1'),
            'cPUIZahlungsdaten': get_safe_value(shopware_order, 'transactionID')
        }

    # First detect the delimiter
    with open(shopware_csv_path, mode='r', encoding='utf-8') as f:
        dialect = csv.Sniffer().sniff(f.read(1024))
        f.seek(0)

        # Read input and write output
        with open(jtl_csv_path, mode='w', encoding='utf-8', newline='') as jtl_file:
            shopware_reader = csv.DictReader(f, delimiter=dialect.delimiter)
            jtl_writer = csv.DictWriter(jtl_file, fieldnames=jtl_header, delimiter='\t')

            jtl_writer.writeheader()

            for shopware_order in shopware_reader:
                jtl_order = transform_order(shopware_order)
                jtl_writer.writerow(jtl_order)

if __name__ == '__main__':
    convert_shopware_to_jtl('s_order_new.csv', 'jtl_orders_d.csv')

# %%
import pandas as pd
from typing import Dict

def update_jtl_ids_only(shopware_file: str, jtl_file: str, output_file: str):
    """
    Updates ONLY the kKunde IDs in JTL Shop data to match Shopware IDs based on email,
    leaving all other columns completely unchanged.

    Args:
        shopware_file: Path to Shopware user data (CSV/Excel)
        jtl_file: Path to JTL Shop customer data (CSV/Excel)
        output_file: Path to save updated JTL data
    """
    try:
        print("Loading data files...")
        # Read files (autodetect CSV/Excel)
        shopware_df = pd.read_csv(shopware_file) if shopware_file.endswith('.csv') else pd.read_excel(shopware_file)
        jtl_df = pd.read_csv(jtl_file) if jtl_file.endswith('.csv') else pd.read_excel(jtl_file)

        print("Creating email to Shopware ID mapping...")
        # Create {email: shopware_id} dictionary
        email_to_shopware_id = {
            str(row['email']).lower(): row['id']
            for _, row in shopware_df.iterrows()
            if pd.notna(row['email'])
        }

        print("Processing JTL data...")
        changes = 0
        # Create copy to preserve original data
        updated_jtl_df = jtl_df.copy()

        for index, row in updated_jtl_df.iterrows():
            if pd.notna(row['cMail']):
                jtl_email = str(row['cMail']).lower()
                if jtl_email in email_to_shopware_id:
                    shopware_id = email_to_shopware_id[jtl_email]
                    if row['kKunde'] != shopware_id:
                        updated_jtl_df.at[index, 'kKunde'] = shopware_id
                        changes += 1
                        print(f"Updated {jtl_email}: {row['kKunde']} → {shopware_id}")

        # Save results
        if output_file.endswith('.csv'):
            updated_jtl_df.to_csv(output_file, index=False)
        else:
            updated_jtl_df.to_excel(output_file, index=False)

        print(f"\nProcess complete. {changes} IDs updated.")
        print(f"Original JTL records: {len(jtl_df)}")
        print(f"Updated file saved to: {output_file}")

    except Exception as e:
        print(f"\nError: {str(e)}")

# Configuration - update these paths
if __name__ == "__main__":
    SHOPWARE_DATA = "shopware_users.csv"  # or .xlsx
    JTL_DATA = "jtl_customers.csv"        # or .xlsx
    OUTPUT_FILE = "jtl_customers_updated.csv"  # or .xlsx

    print("Starting JTL kKunde ID update process...")
    update_jtl_ids_only(SHOPWARE_DATA, JTL_DATA, OUTPUT_FILE)
# Out:
# Streaming output truncated to the last 5000 lines.
# Updated vschindlbeck@gmail.com: 4884 → 5173
# Updated bernhardengel@gmx.de: 4885 → 5174
# Updated ole.muehlfeld@gmx.de: 4886 → 5175
# Updated julia@beischaefers.de: 4887 → 5176
# Updated ursulafischer80@hotmail.com: 4888 → 5177
# Updated ursula.prokopp@kps-partner.at: 4889 → 5178
# Updated joho65@gmx.net: 4890 → 5179
# Updated hermes.da@t-online.de: 4891 → 5180
# Updated pep.haug@gmail.com: 4892 → 5182
# Updated amazon@logo-cash.de: 4893 → 5183
# Updated martin.wirt@gmx.de: 4894 → 5184
# Updated idanzeige@gmail.com: 4895 → 5185
# Updated schallhart@gmx.at: 4896 → 5186
# Updated bastian.jann@gmx.de: 4897 → 5187
# Updated d_schill@web.de: 4898 → 5188
# Updated kfz-moritz@web.de: 4899 → 5189
# Updated linda-87@t-online.de: 4900 → 5190
# Updated flino@mail.de: 4901 → 5191
# Updated roth_schuler@mac.com: 4902 → 5192
# Updated tenidde2291@gmail.com: 4903 → 5193
# Updated dr.petra.walter@gmx.de: 4904 → 5194
# Updated eissler-eissler@web.de: 4905 → 5195
# Updated maurinezaratin@hotmail.com: 4906 → 5196
# Updated andrea_schleissmann@web.de: 4907 → 5197
# Updated stadtmarina-gemuenden@web.de: 4908 → 5198
# Updated batjakmail@aol.de: 4909 → 5199
# Updated i.zinkkann@gmx.de: 4910 → 5200
# Updated uwe.kaltenbach@gmx.de: 4911 → 5201
# Updated mzaratin.vet@gmail.com: 4912 → 5202
# Updated tobi.zernicke@googlemail.com: 4913 → 5203
# Updated saschafolville@gmx.de: 4914 → 5204
# Updated claudia.lanz@gmx.de: 4915 → 5974
# Updated susanne.peevor@web.de: 4916 → 5206
# Updated helgejung@gmx.de: 4917 → 5207
# Updated simlow24@alice.de: 4918 → 5208
# Updated marietta.triebs@gmx.de: 4919 → 5270
# Updated maria@meyer-berg.de: 4920 → 5210
# Updated knoll.alexej@gmail.com: 4921 → 5211
# Updated traianuss@hotmail.com: 4922 → 5212
# Updated leopold43@gmail.com: 4923 → 5213
# Updated alexkelle89@googlemail.com: 4924 → 5215
# Updated norablank@web.de: 4925 → 5216
# Updated roma.stephan@gmal.com: 4926 → 5217
# Updated keule05061989@gmx.de: 4927 → 5218
# Updated battak96@web.de: 4928 → 5219
# Updated simon.matausch@web.de: 4929 → 5222
# Updated kraemer.stefan@gmx.net: 4930 → 5223
# Updated emmelie27703@gmx.de: 4931 → 5224
# Updated braun-event@gmx.de: 4932 → 5225
# Updated b.dorotheahesse@gmail.com: 4933 → 5226
# Updated m.parensen@gmx.de: 4934 → 5227
# Updated ham.seramy@live.fr: 4935 → 5228
# Updated hatschepsut7710@yahoo.de: 4936 → 5229
# Updated ulf.herrmann4@gmail.com: 4937 → 5230
# Updated damiano@ineachmoment.de: 4938 → 5231
# Updated clinnemann@web.de: 4939 → 5232
# Updated nlindberg15@icloud.com: 4940 → 5233
# Updated nadine.kuess@oviva.com: 4941 → 5234
# Updated sven_sievers@web.de: 4942 → 5235
# Updated michael-diestel@web.de: 4943 → 6961
# Updated simone-bieler@htp-tel.de: 4944 → 5237
# Updated ab_deschain@web.de: 4945 → 5238
# Updated kilz.andrea@gmail.com: 4946 → 5239
# Updated anniwegner@outlook.de: 4947 → 5240
# Updated heavens-dj@gmx.de: 4948 → 5241
# Updated samitheapple@gmail.com: 4949 → 5242
# Updated manuel.sichelmeier@gmx.de: 4950 → 5243
# Updated r.kortschewski1997@web.de: 4951 → 5244
# Updated inkakesch@t-online.de: 4952 → 5245
# Updated deutlich_steinkreis.0b@icloud.com: 4953 → 5246
# Updated prewitt@gmx.de: 4954 → 5247
# Updated gunnar@lineandcircle.co: 4955 → 5248
# Updated reimermalexandra@gmail.com: 4956 → 5249
# Updated manuela.seebald@gmx.de: 4957 → 5250
# Updated sikesa@gmx.de: 4958 → 5251
# Updated clara_prokein@gmx.net: 4959 → 5254
# Updated familie.windsheimer@t-online.de: 4960 → 5253
# Updated goebelhenke@online.de: 4961 → 5255
# Updated annip80@gmx.net: 4962 → 5256
# Updated r.birrer.matsch@gmail.com: 4963 → 5257
# Updated christian.schulze78@yahoo.de: 4964 → 5258
# Updated christine.ortlieb@web.de: 4965 → 5259
# Updated liri29@gmx.de: 4966 → 5260
# Updated marlene.killesreiter@gmail.com: 4967 → 5261
# Updated sviti80@yahoo.com: 4968 → 5262
# Updated steffiii-streuffert@live.de: 4969 → 5263
# Updated claudia.heyder@gmx.de: 4970 → 5264
# Updated mail@buschenhagen.berlin: 4971 → 5265
# Updated till.weigel@web.de: 4972 → 5266
# Updated einbrodt@me.com: 4973 → 5267
# Updated heise.corinna@web.de: 4974 → 5268
# Updated dsydow@gmx.net: 4975 → 5271
# Updated utavonderwipper@aol.com: 4976 → 5272
# Updated selent.sabine@gmx.de: 4977 → 5273
# Updated cstel377@gmail.com: 4978 → 5274
# Updated marta.schlonsok@g.comail.com: 4979 → 5275
# Updated bernhard.stosik@asamnet.de: 4980 → 5276
# Updated alenabrucks@gmail.com: 4981 → 5277
# Updated hectorbelascoarans@gmail.com: 4982 → 5278
# Updated burkhard.henneken@gmx.de: 4983 → 5279
# Updated k-voelkening@gmx.de: 4984 → 5280
# Updated ewald.mick@eneacon.com: 4985 → 5281
# Updated dietmar.karbach@web.de: 4986 → 5282
# Updated sgarwels@googlemail.com: 4987 → 5283
# Updated kflady@online.de: 4988 → 5284
# Updated julia@iflinger.de: 4989 → 5285
# Updated jana.nojack@gmx.de: 4990 → 5286
# Updated sunshine.lisa@web.de: 4991 → 5287
# Updated kleinjannis@gmx.net: 4992 → 5288
# Updated pbronkhorst@upcmail.nl: 4993 → 5289
# Updated anne.s.mueller@gmail.com: 4994 → 5290
# Updated yavor_mihaylov@yahoo.com: 4995 → 5291
# Updated marialambrecht66@gmail.com: 4996 → 5292
# Updated jeromekost@gmail.com: 4997 → 5293
# Updated boenischsebastian@yahoo.de: 4998 → 5294
# Updated hkmp5@gmx.de: 4999 → 5295
# Updated klaushaeger@gmx.de: 5000 → 5296
# Updated amazon@gunnarmeyer.net: 5001 → 5297
# Updated maelein@live.de: 5002 → 5298
# Updated chris.lok75@web.de: 5003 → 5299
# Updated ntirhard@free.fr: 5004 → 5300
# Updated d.bloedow@web.de: 5005 → 5301
# Updated chernina.alla@googlemail.com: 5006 → 5302
# Updated joerna.dayena@googlemail.com: 5007 → 5303
# Updated katja@die-brauns.de: 5008 → 5304
# Updated christinlex@web.de: 5009 → 5305
# Updated christiane.hornig@aol.de: 5010 → 5306
# Updated cvetter483@gmail.com: 5011 → 5307
# Updated mail@janniksu.de: 5012 → 5308
# Updated beate_von_hall@web.de: 5013 → 5309
# Updated bock-alexander@web.de: 5014 → 5310
# Updated louisegonda@gmail.com: 5015 → 5311
# Updated katharina@rehmsclan.de: 5016 → 5312
# Updated michael.jetter@gmx.de: 5017 → 5313
# Updated pettypatrik.thom1976@gmail.com: 5018 → 5314
# Updated kristin-rudolph80@gmx.de: 5019 → 5315
# Updated daniela879@web.de: 5020 → 5316
# Updated isabella.stange@gmx.de: 5021 → 5317
# Updated km02@me.com: 5022 → 5318
# Updated ur.feuchter@arcor.de: 5023 → 5319
# Updated f.thole@me.com: 5024 → 5320
# Updated sepanta@gmx.de: 5025 → 5321
# Updated martin.tirol@chello.at: 5026 → 5322
# Updated oliver.bienek@web.de: 5027 → 5323
# Updated wagener-c@t-online.de: 5028 → 5324
# Updated julia@klewinghaus-online.de: 5029 → 5325
# Updated m_schwendi@gmx.de: 5030 → 5326
# Updated susanne.boehmer253@gmail.com: 5031 → 5327
# Updated robi-dani@web.de: 5032 → 5328
# Updated caroline.schroeder2@t-online.de: 5033 → 5442
# Updated davidadomeith@gmail.com: 5034 → 5330
# Updated lillasarkadi@hotmail.com: 5035 → 5331
# Updated tanja.g.1987@hotmail.com: 5036 → 5332
# Updated stefan.doerr81@web.de: 5037 → 5333
# Updated carsten@sbick.de: 5038 → 5334
# Updated timo.torz@rub.de: 5039 → 5335
# Updated ickediekati@gmx.de: 5040 → 5336
# Updated lena-k-rose@web.de: 5041 → 5337
# Updated christoph.naeger@fau.de: 5042 → 5338
# Updated e.karsten@gmx.net: 5043 → 5339
# Updated zuhalhuseyin@yahoo.com: 5044 → 5340
# Updated sarahgehrmann2000@gmail.com: 5045 → 5341
# Updated anna.hagedorn@gmx.ch: 5046 → 5342
# Updated skoschmider@web.de: 5047 → 5343
# Updated monikaburcek@web.de: 5048 → 5344
# Updated ergenmeltem@yahoo.com: 5049 → 5345
# Updated lauratesdorpf@yahoo.de: 5050 → 5346
# Updated eva_nelson@web.de: 5051 → 5347
# Updated horst.schneider0507@gmail.com: 5052 → 5348
# Updated lupus-erfordi@arcor.de: 5053 → 5349
# Updated eulentini@outlook.de: 5054 → 5350
# Updated oswaldelke@googlemail.com: 5055 → 5351
# Updated larissa.rahlff@web.de: 5056 → 5352
# Updated oliver.renken@gmail.com: 5057 → 5353
# Updated nina_grohn@web.de: 5058 → 5354
# Updated cookie_fancier@web.de: 5059 → 5355
# Updated victoria.mandlmaier@gmx.de: 5060 → 5356
# Updated leahangela72@gmail.com: 5061 → 5357
# Updated caro.stern16@gmail.com: 5062 → 5358
# Updated eich.katharina@web.de: 5063 → 5360
# Updated a-s.heinz@web.de: 5064 → 5361
# Updated anlu7@web.de: 5065 → 5362
# Updated an.boe@yahoo.com: 5066 → 5363
# Updated dgroeschler@t-online.de: 5067 → 5364
# Updated kuhn.yulia@googlemail.com: 5068 → 5371
# Updated alex_reich@icloud.com: 5069 → 5366
# Updated jennifer.huelsduenker@gmail.com: 5070 → 5367
# Updated post@dj-hille.de: 5071 → 5368
# Updated klaus.gerig@outlook.de: 5072 → 5369
# Updated kl.hoelzer@t-online.de: 5073 → 5370
# Updated kerstin.port@arcor.de: 5074 → 5372
# Updated ursula.donath-rilke@gmx.de: 5075 → 5373
# Updated sabineschwiertz@gmx.de: 5076 → 5374
# Updated julia-erdmann@gmx.net: 5077 → 5375
# Updated imihailidis@gmail.com: 5078 → 5376
# Updated w1t8g0v7s@mozmail.com: 5079 → 5377
# Updated bernd.schwing@t-online.de: 5080 → 5378
# Updated davidgrill@gmx.de: 5081 → 5379
# Updated elisabeth_r@t-online.de: 5082 → 5380
# Updated stefan.boever@t-online.de: 5083 → 5381
# Updated rgre850656@aol.com: 5084 → 5382
# Updated moehring.matthias@web.de: 5085 → 5383
# Updated arankahiller@posteo.de: 5086 → 5384
# Updated nicole-pankow@gmx.de: 5087 → 5385
# Updated carolin181@aol.com: 5088 → 5386
# Updated marco.hemmeter@gmail.com: 5089 → 5387
# Updated weber.thomas@email.de: 5090 → 5388
# Updated ebuehr@gmx.de: 5091 → 5389
# Updated katharina.gaedke@freenet.de: 5092 → 5391
# Updated yvonnepankonin@web.de: 5093 → 5392
# Updated elke-alpen@gmx.de: 5094 → 5393
# Updated joost@wilbrink.ws: 5095 → 5394
# Updated brit.bohnhoff@hotmail.de: 5096 → 5395
# Updated e.bierbach@freenet.de: 5097 → 5396
# Updated pummelbaer@gmx.de: 5098 → 5397
# Updated gordon.peric@gmail.com: 5099 → 5398
# Updated savarovski91@web.de: 5100 → 5399
# Updated tanja.ebenhoech@gmx.de: 5101 → 5400
# Updated effe_bl@hotmail.com: 5102 → 5401
# Updated ute.hermann@outlook.com: 5103 → 5402
# Updated haberlandreas@web.de: 5104 → 5403
# Updated elmarschopper@gmail.com: 5105 → 5404
# Updated anna_hardt@hotmail.com: 5106 → 5405
# Updated thielekatrin@hotmail.de: 5107 → 5406
# Updated bernermartina@web.de: 5108 → 5407
# Updated juliecool80@hotmail.com: 5109 → 5408
# Updated d.fens-80@gmx.at: 5110 → 5409
# Updated andrea@koster-maschinenbau.de: 5111 → 5410
# Updated gaudlitz78@web.de: 5112 → 5413
# Updated ines.ini@web.de: 5113 → 5412
# Updated ch.berghofer@web.de: 5114 → 5414
# Updated mkrautkraemer@hotmail.de: 5115 → 5415
# Updated birgit_friedl@t-online.de: 5116 → 5416
# Updated michael.baio@mail.de: 5117 → 5417
# Updated azargus@googlemail.com: 5118 → 5418
# Updated i.m.lockowandt-@t-online.de: 5119 → 5419
# Updated guenther.heuss@web.de: 5120 → 5421
# Updated susanne.kappel@t-online.de: 5121 → 5422
# Updated dinirosi@web.de: 5122 → 5423
# Updated heiko.kraemer@gmx.de: 5123 → 5424
# Updated markus.schoellhuber@outlook.com: 5124 → 5425
# Updated janine.kesselheim@gmail.com: 5125 → 5426
# Updated silviabonitz@web.de: 5126 → 5427
# Updated christina.in.hannover@freenet.de: 5127 → 7938
# Updated andreas.hanff@gmx.de: 5128 → 5429
# Updated birgit272@googlemail.com: 5129 → 5430
# Updated antonio_tarabay@hotmail.de: 5130 → 7284
# Updated tine.sonnenschein@gmx.de: 5131 → 5433
# Updated mga.hecht@gmail.com: 5132 → 5434
# Updated hamoeriden@gmx.de: 5133 → 5435
# Updated conradi.magdeburg@gmx.de: 5134 → 6446
# Updated gartnerp@aol.com: 5135 → 5437
# Updated hschwabauer22@gmail.com: 5136 → 5438
# Updated roybrzozowski@gmx.de: 5137 → 5439
# Updated marquard-3d@gmx.de: 5138 → 5440
# Updated we-may@t-online.de: 5139 → 5441
# Updated nicigreulich@aol.com: 5140 → 5443
# Updated m-roer@online.de: 5141 → 5444
# Updated nina.animalart@web.de: 5142 → 7428
# Updated paschke.hartmut@t-online.de: 5143 → 5447
# Updated florian251113@gmail.com: 5144 → 5448
# Updated erwin.gramm@gmail.com: 5145 → 5449
# Updated yuni.rottmann@gmx.de: 5146 → 5450
# Updated peter.zilbauer@gmx.de: 5147 → 5451
# Updated su.heinemann@web.de: 5148 → 5452
# Updated anna-marie@die-otts.de: 5149 → 5453
# Updated kls.kroeger@web.de: 5150 → 5458
# Updated soma.wasser@gmail.com: 5151 → 5456
# Updated jessy1984@t-online.de: 5152 → 5461
# Updated miriam@buholzer.de: 5153 → 5459
# Updated judith@dreher-web.de: 5154 → 5460
# Updated melina.m.kruse@gmail.com: 5155 → 5462
# Updated henrike.heile@web.de: 5156 → 5463
# Updated tanja.schweitzer0407@web.de: 5157 → 5464
# Updated martin.wans@googlemail.com: 5158 → 5465
# Updated johannes@schlichenmaier.info: 5159 → 5466
# Updated christinerode@gmx.de: 5160 → 5467
# Updated hofchr15@web.de: 5161 → 5468
# Updated yannickphilipp1712@gmail.com: 5162 → 5469
# Updated malukra@gmail.com: 5163 → 5470
# Updated heidi@maheigue.de: 5164 → 5471
# Updated kristina.schroeder87@googlemail.com: 5165 → 5472
# Updated nokikana@t-online.de: 5166 → 5473
# Updated maria.dressel@gmx.net: 5167 → 9125
# Updated gabriele-loeffler@t-online.de: 5168 → 5475
# Updated areklat.einkaufen@gmail.com: 5169 → 5476
# Updated verditante@web.de: 5170 → 5477
# Updated sumairagottschalk@gmail.com: 5171 → 5478
# Updated astrid.boenning.goette@gmail.com: 5172 → 5479
# Updated katrin.opiolka@gmx.de: 5173 → 5480
# Updated alex-01988@hotmail.com: 5174 → 5481
# Updated priska.schroeder@gmx.ch: 5175 → 5482
# Updated fraudegroot@gmail.com: 5176 → 5483
# Updated jakob-rene@web.de: 5177 → 5484
# Updated dirk_tuschl@web.de: 5178 → 5485
# Updated fabian.pulver1705@gmail.com: 5179 → 5486
# Updated sansis@freenet.de: 5180 → 5487
# Updated isabella.risorgi@gmail.com: 5181 → 5488
# Updated tiberiu.sufitchi@gmail.com: 5182 → 5489
# Updated tancy@gmx.net: 5183 → 5490
# Updated christine.pruetz@gmail.com: 5184 → 5491
# Updated vazquez-gbs-st.annen@kvs-hh.de: 5185 → 5492
# Updated christian.jahn71@yahoo.de: 5186 → 5494
# Updated moni-reisser@t-online.de: 5187 → 5495
# Updated helenabeetz@posteo.de: 5188 → 5496
# Updated diesabbel@me.com: 5189 → 5497
# Updated sina98@gmx.de: 5190 → 5498
# Updated info@atelier-braun.de: 5191 → 5499
# Updated hartmann-wedell@t-online.de: 5192 → 5500
# Updated hjarps@aol.com: 5193 → 5501
# Updated anja.ohlinger@yahoo.de: 5194 → 5502
# Updated ryser@jorynet.com: 5195 → 5503
# Updated m_ahlers@web.de: 5196 → 5506
# Updated urban.holger@gmail.com: 5197 → 5507
# Updated meyerenrico@gmx.net: 5198 → 8276
# Updated sandra-greuter@gmx.de: 5199 → 5509
# Updated maxim-von-prodigy@gmx.ch: 5200 → 5510
# Updated nils2111@gmx.de: 5201 → 5511
# Updated tanja.schweigardt@gmx.de: 5202 → 5512
# Updated jacob-evers@hotmail.com: 5203 → 5513
# Updated laura6@gmx.de: 5204 → 5514
# Updated qigongyangsheng2016@gmail.com: 5205 → 5515
# Updated dosaka@mail.de: 5206 → 5516
# Updated tina.taube@gmx.de: 5207 → 5517
# Updated grunow7@web.de: 5208 → 5518
# Updated sven.v.beuningen@gmx.de: 5209 → 5519
# Updated brigitte_schatz@web.de: 5210 → 5520
# Updated petra.wilkens@gmx.net: 5211 → 5522
# Updated lueth.niklas@gmail.com: 5212 → 5523
# Updated christa.kill@t-online.de: 5213 → 5524
# Updated pasurka@t-online.de: 5214 → 5525
# Updated kerstin@vonwieding.net: 5215 → 5526
# Updated nicklas-simone@hotmail.de: 5216 → 5527
# Updated ina-krumbiegel@web.de: 5217 → 5528
# Updated mail-az1@acssoft.de: 5218 → 5529
# Updated mail@bettyhagemann.com: 5219 → 5530
# Updated anita.koch@oekonom.ch: 5220 → 5531
# Updated wolwa@gmx.de: 5221 → 5533
# Updated daniel.sommer83@web.de: 5222 → 5534
# Updated dany.aubriet@gmail.com: 5223 → 5535
# Updated alexandra.h.enkrodt@t-online.de: 5224 → 5536
# Updated lars.wegers@gmx.de: 5225 → 5537
# Updated katingo@kabelmail.de: 5226 → 5538
# Updated micha.voit@web.de: 5227 → 5539
# Updated nina@csffm.de: 5228 → 5540
# Updated kaatje01@gmail.com: 5229 → 5541
# Updated katja_reiss@gmx.ch: 5230 → 5542
# Updated jasminwiese92@freenet.de: 5231 → 5543
# Updated kerstinblesin@freenet.de: 5232 → 5544
# Updated robert.rebitsch@uibk.ac.at: 5233 → 5545
# Updated alexander.dirks82@gmail.com: 5234 → 5546
# Updated kinga1980@gmail.com: 5235 → 5547
# Updated alex.tschoepe@gmx.de: 5236 → 5548
# Updated heidihoelzer@gmail.com: 5237 → 5549
# Updated heidihoelzer11@gmail.com: 5238 → 5550
# Updated patricks_castle@web.de: 5239 → 5551
# Updated alexanderbirk@freenet.de: 5240 → 5552
# Updated laura.dilthey@web.de: 5241 → 5553
# Updated andreadiek2505@gmail.com: 5242 → 5554
# Updated felix@nunninger.de: 5243 → 5555
# Updated eva.neufeld@gmail.com: 5244 → 5556
# Updated marion8680@freenet.de: 5245 → 5558
# Updated 07022hiphop2@web.de: 5246 → 5559
# Updated igolfrichter@gmail.com: 5247 → 5560
# Updated christianeinacker@yahoo.de: 5248 → 5561
# Updated ursula-schaal@gmx.de: 5249 → 5562
# Updated moehlfrau@gmx.de: 5250 → 5563
# Updated tabea.schalk@gmx.de: 5251 → 5564
# Updated anna15803@web.de: 5252 → 5565
# Updated iris.leininger@gmx.de: 5253 → 5566
# Updated chkn@gmx.net: 5254 → 5567
# Updated lisafaber@live.de: 5255 → 5568
# Updated karin.28071958@gmail.com: 5256 → 5569
# Updated jutta.oebels@aol.com: 5257 → 5570
# Updated schedel.nicky@web.de: 5258 → 5571
# Updated pietsch.carla@googlemail.com: 5259 → 5572
# Updated s.kaffarnik@gmx.de: 5260 → 5573
# Updated andreas.thurn@uni-hohenheim.de: 5261 → 5574
# Updated csali@gmx.de: 5262 → 5575
# Updated girafasr@hotmail.com: 5263 → 5576
# Updated bkrogner@gmail.com: 5264 → 5578
# Updated rjtklein@gmail.com: 5265 → 5579
# Updated mima-sa@web.de: 5266 → 5580
# Updated seilbubsimon@gmail.com: 5267 → 5582
# Updated f.friederiszick@web.de: 5268 → 5583
# Updated larsrobel@web.de: 5269 → 5584
# Updated irina-speith@gmx.de: 5270 → 5585
# Updated tobias-ehrich@hotmail.de: 5271 → 5586
# Updated l.menner@web.de: 5272 → 5587
# Updated tanja.hochheim96@web.de: 5273 → 5588
# Updated manuel.woelfle@gmx.net: 5274 → 5589
# Updated marcusdanau@gmail.com: 5275 → 5590
# Updated juleguegel@web.de: 5276 → 5591
# Updated ulrike.jonas@t-online.de: 5277 → 5592
# Updated katherina.schmetan@gmx.de: 5278 → 5593
# Updated daniela.marion.boettcher@gmail.com: 5279 → 5621
# Updated vre-na@gmx.de: 5280 → 5595
# Updated rilu26@web.de: 5281 → 5606
# Updated sebastian@sebastian-furth.de: 5282 → 5597
# Updated tina.gleixner@gmx.de: 5283 → 5598
# Updated kristina.belker@gmx.de: 5284 → 5599
# Updated annedore.thiersch@gmx.de: 5285 → 5600
# Updated nicole030975@hotmail.com: 5286 → 5601
# Updated puls_mandy@freenet.de: 5287 → 5602
# Updated astridschroeder1@gmx.net: 5288 → 5603
# Updated wiebkediercks@kabelmail.de: 5289 → 5604
# Updated trost0104@gmail.com: 5290 → 5605
# Updated thomas.faessler@t-online.de: 5291 → 5607
# Updated tatiana.eisenhuth@gmail.com: 5292 → 5608
# Updated f.strobach@mail.com: 5293 → 5609
# Updated antje.rz@web.de: 5294 → 5610
# Updated jules.nudelsalat@gmx.net: 5295 → 5611
# Updated koeln199@freenet.de: 5296 → 5612
# Updated sauerlena@hotmail.com: 5297 → 5613
# Updated philipp.wagner@wagro.de: 5298 → 5614
# Updated tomy.d@online.de: 5299 → 5615
# Updated sandra-jeanmaddox@web.de: 5300 → 5616
# Updated lucymaul@icloud.com: 5301 → 5617
# Updated alexandra.thomas7@outlook.be: 5302 → 5618
# Updated meister-becht@gmx.de: 5303 → 5619
# Updated sauer.juditheva@web.de: 5304 → 5620
# Updated verena-kuffer@gmx.de: 5305 → 5622
# Updated natascha.gerweck@gmx.de: 5306 → 5623
# Updated henry.adler@gmx.de: 5307 → 5624
# Updated m-kufeld@t-online.de: 5308 → 5625
# Updated judy_@gmx.net: 5309 → 5626
# Updated eheleute.grimm@gmail.com: 5310 → 5627
# Updated dominik.weyland@gmx.de: 5311 → 5628
# Updated manni.rabiega@gmx.net: 5312 → 5629
# Updated menzelroe@t-online.de: 5313 → 5630
# Updated rudolf.schoemann@gmail.com: 5314 → 5631
# Updated h.trimbusch@web.de: 5315 → 5632
# Updated u.muellhaupt@bluewin.ch: 5316 → 5633
# Updated daniela-bromm@gmx.de: 5317 → 5634
# Updated s.fussholz@gmx.de: 5318 → 5635
# Updated jp.alder@hotmail.com: 5319 → 5636
# Updated peter.kowatschew@gmx.de: 5320 → 5637
# Updated hannah.svh@gmx.de: 5321 → 5638
# Updated rebeca.delucia@mail.ch: 5322 → 5639
# Updated wdieckmann2@icloud.com: 5323 → 5640
# Updated smiley_pat_3@yahoo.de: 5324 → 5641
# Updated p.krane@web.de: 5325 → 5642
# Updated nina.augsburger@web.de: 5326 → 5643
# Updated jschombi@hotmail.com: 5327 → 5644
# Updated s.hartmann1@gmx.net: 5328 → 5645
# Updated tina.hecky@gmail.com: 5329 → 5664
# Updated heckyhexe@googlemail.com: 5330 → 5647
# Updated winfriedhierl@gmail.com: 5331 → 7367
# Updated doroboehne@gmx.de: 5332 → 5649
# Updated ebertz.michael@gmail.com: 5333 → 5650
# Updated pierre.olthoff@t-online.de: 5334 → 5651
# Updated mstobbe@avoplanung.de: 5335 → 5652
# Updated service@mediagnose.de: 5336 → 5653
# Updated xx_andreabakker_xx@yahoo.de: 5337 → 5654
# Updated kristina.zelder@t-online.de: 5338 → 5655
# Updated schierenbeck@gmx.net: 5339 → 5656
# Updated annasabel@gmx.de: 5340 → 5657
# Updated rschuetzdeller@gmail.com: 5341 → 5658
# Updated dr.inga.hesse@gmail.com: 5342 → 5659
# Updated bdahm@gmx.net: 5343 → 5660
# Updated bittlinger.t@gmx.de: 5344 → 5661
# Updated mariella.kossatz@gmx.de: 5345 → 5662
# Updated max.knoll@posteo.de: 5346 → 5663
# Updated lindawittkowski@web.de: 5347 → 5665
# Updated ilseknogl@web.de: 5348 → 5666
# Updated ingo.bastigkeit@gmx.de: 5349 → 5667
# Updated kati87@gmx.de: 5350 → 5668
# Updated j.kirschee@t-online.de: 5351 → 5669
# Updated janssen-tanja@freenet.de: 5352 → 5670
# Updated janet.garbe@gmx.de: 5353 → 5671
# Updated deliah_bolesta@hotmail.de: 5354 → 5674
# Updated henning.roose@web.de: 5355 → 5673
# Updated markus.finzel.andro@googlemail.com: 5356 → 5675
# Updated reginapal@gmx.de: 5357 → 5676
# Updated hermann.kress@gmx.de: 5358 → 5677
# Updated sabine.koob@gmx.net: 5359 → 5678
# Updated cwer981@gmx.de: 5360 → 5679
# Updated siggiklues@gmail.com: 5361 → 5680
# Updated maria-christin81@gmx.de: 5362 → 5681
# Updated ericmue@web.de: 5363 → 5683
# Updated uta.gruyters@t-online.de: 5364 → 5685
# Updated susanne.hasch@gmx.de: 5365 → 5686
# Updated elisabeth.thein@web.de: 5366 → 5687
# Updated jessica-odenbreit@t-online.de: 5367 → 5688
# Updated m.bodenmueller89@gmail.com: 5368 → 5689
# Updated david.sere@gmail.com: 5369 → 5690
# Updated speedy-jenny@web.de: 5370 → 5692
# Updated a.hellfajer@gmail.com: 5371 → 5694
# Updated mariekedefrel@hotmail.com: 5372 → 5695
# Updated janjcbsn@gmail.com: 5373 → 5697
# Updated mehlberg.robin@googlemail.com: 5374 → 5699
# Updated geiser.daniela@web.de: 5375 → 5700
# Updated froschi207@web.de: 5376 → 5701
# Updated christoph.gailler@web.de: 5377 → 5702
# Updated reagenz_baumstamm01@icloud.com: 5378 → 5703
# Updated katrin-goldhammer@t-online.de: 5379 → 5705
# Updated kathi.kunz1@gmx.de: 5380 → 5706
# Updated becki7309@aol.com: 5381 → 5707
# Updated c_baeumer@gmx.net: 5382 → 5708
# Updated diesselleila@gmail.com: 5383 → 5709
# Updated j-wuttke@web.de: 5384 → 5710
# Updated andreas.koch@gbg-ag.com: 5385 → 5711
# Updated carolienvanbastelaer@hotmail.com: 5386 → 5712
# Updated nicpit2002@gmail.com: 5387 → 5713
# Updated andreashannajakob@gmail.com: 5388 → 5714
# Updated tanjalobgesang@gmx.de: 5389 → 5715
# Updated laura@getfetchr.com: 5390 → 5717
# Updated emertens82@gmail.com: 5391 → 5718
# Updated oraand78@alice.it: 5392 → 5719
# Updated lydia@go4more.de: 5393 → 5720
# Updated angeliquehinrich@gmx.net: 5394 → 5721
# Updated sarsura342@gmail.com: 5395 → 5722
# Updated a_zumbrunn@bluemail.ch: 5396 → 5723
# Updated brand_shop@t-online.de: 5397 → 5724
# Updated mareike.wippermann@web.de: 5398 → 5726
# Updated roennie@gmx.net: 5399 → 5727
# Updated karin@mhcomputer.de: 5400 → 5728
# Updated leejlenssen@gmail.com: 5401 → 5729
# Updated jenny01.gross@hotmail.de: 5402 → 5730
# Updated endresmarie@aol.com: 5403 → 5731
# Updated nadine.huck@huck.net: 5404 → 5732
# Updated engelbengel17401@yahoo.de: 5405 → 5733
# Updated anja.waldstein@icloud.com: 5406 → 5734
# Updated joerg.flintrop@gmx.de: 5407 → 5735
# Updated agehrmann@gmx.de: 5408 → 5736
# Updated ellen.oestreicher@web.de: 5409 → 5737
# Updated josibeck781@gmail.com: 5410 → 5738
# Updated muedag2@web.de: 5411 → 5739
# Updated nici090290@gmail.com: 5412 → 5740
# Updated antoine.durand71@orange.fr: 5413 → 5741
# Updated c8soul@gmail.com: 5414 → 5743
# Updated jonas.martina@web.de: 5415 → 5744
# Updated malikazerdeb@gmail.com: 5416 → 5745
# Updated annalena.hehemann@icloud.com: 5417 → 5746
# Updated milaevers@icloud.com: 5418 → 5747
# Updated dustyn2001@gmx.de: 5419 → 5748
# Updated h_str@gmx.de: 5420 → 5749
# Updated inaklose@hotmail.com: 5421 → 5750
# Updated sammifadl@hotmail.com: 5422 → 5751
# Updated hannavonhummel@web.de: 5423 → 5752
# Updated info@weisgerber.com: 5424 → 5753
# Updated jensenisler@gmail.com: 5425 → 5754
# Updated irade_23@hotmail.de: 5426 → 5755
# Updated niklasvk@gmail.com: 5427 → 5756
# Updated gloeckler.m@gmx.de: 5428 → 5757
# Updated klausmarr@web.de: 5429 → 5758
# Updated seb.trumpfheller23@gmail.com: 5430 → 7115
# Updated renner_frank@gmx.de: 5431 → 5760
# Updated lehmannclimo@web.de: 5432 → 5761
# Updated andre_weinhold@yahoo.com: 5433 → 5762
# Updated leakatharinakrug@gmail.com: 5434 → 5763
# Updated raffael.doerig@bluewin.ch: 5435 → 5764
# Updated bollegebhardt@web.de: 5436 → 5765
# Updated aline-lini@gmx.de: 5437 → 5766
# Updated friederikeb@gmx.net: 5438 → 5767
# Updated ramona@myleonhardt.de: 5439 → 5788
# Updated kauderrobert@web.de: 5440 → 5769
# Updated rmayberlin@t-online.de: 5441 → 5770
# Updated juliafrankjulia@gmx.de: 5442 → 5771
# Updated hubert.kleber@freenet.de: 5443 → 5772
# Updated hofmann@aekwl.de: 5444 → 5773
# Updated thomas.raese@t-online.de: 5445 → 5774
# Updated liloknuelle@outlook.de: 5446 → 5775
# Updated ntraulsen@gmx.de: 5447 → 5777
# Updated klotschentommy@gmx.de: 5448 → 5778
# Updated kaschtanka-m@gmx.de: 5449 → 5779
# Updated dartanjo04@gmail.com: 5450 → 5780
# Updated annika.steinhardt@web.de: 5451 → 5781
# Updated kkalfhaus@googlemail.com: 5452 → 5782
# Updated mathias@klaeui.de: 5453 → 5783
# Updated nicoletaube75@gmail.com: 5454 → 5784
# Updated christoph.gottlieb@gmail.com: 5455 → 5785
# Updated thomas.kappl@web.de: 5456 → 5786
# Updated raistlin-df@gmx.de: 5457 → 5787
# Updated julia.bergermann@gmx.de: 5458 → 5789
# Updated anke.umlandt@t-online.de: 5459 → 5790
# Updated sabine.buchstab@web.de: 5460 → 5791
# Updated schmiraf@gmail.com: 5461 → 5792
# Updated viola_frankus@hotmail.de: 5462 → 5795
# Updated maxsteinhardt@gmx.de: 5463 → 5796
# Updated marlenica01@gmx.net: 5464 → 5797
# Updated annemueller85@yahoo.de: 5465 → 5798
# Updated e4e5lc4lc5@t-online.de: 5466 → 5799
# Updated verena.geyer@web.de: 5467 → 5800
# Updated elselotte21@googlemail.com: 5468 → 5801
# Updated n.eimers@gmx.de: 5469 → 5802
# Updated jakobssandra@t-online.de: 5470 → 5803
# Updated m.nather@gmx.de: 5471 → 5804
# Updated manuela.schnalzer@gmail.com: 5472 → 5805
# Updated stephan.koslitz@gmx.net: 5473 → 5806
# Updated s.walter1182@gmail.com: 5474 → 5807
# Updated n.pascal85@yahoo.de: 5475 → 5808
# Updated s.wolf89@web.de: 5476 → 5809
# Updated millet-julien@outlook.fr: 5477 → 5810
# Updated info@wittenberg-event.de: 5478 → 5811
# Updated fpiayda@gmx.de: 5479 → 5812
# Updated foerderreuther@hm.edu: 5480 → 5813
# Updated martin@geipel.at: 5481 → 5814
# Updated tamnuri@gmx.de: 5482 → 5815
# Updated jana.lindenborn@gmx.de: 5483 → 5816
# Updated mitkova.maya@gmail.com: 5484 → 5817
# Updated nando.pahnke@gmail.com: 5485 → 5818
# Updated markushollaender740@gmail.com: 5486 → 5819
# Updated nando.zickgraf@gmail.com: 5487 → 5820
# Updated jennifer.doege@web.de: 5488 → 5822
# Updated cschlagmann@t-online.de: 5489 → 5823
# Updated mirco_b@gmx.de: 5490 → 5824
# Updated lagushka@web.de: 5491 → 5825
# Updated netalia@gmx.de: 5492 → 5826
# Updated johannes.liendl-kroell@outlook.com: 5493 → 5827
# Updated torstenbrock@gmx.de: 5494 → 5828
# Updated julia.olesen@gmx.de: 5495 → 5829
# Updated j.petering@gmx.de: 5496 → 5830
# Updated sandrastruller@yahoo.de: 5497 → 5831
# Updated markus_superstar@gmx.net: 5498 → 5832
# Updated ank17@posteo.org: 5499 → 5833
# Updated klera@web.de: 5500 → 5835
# Updated wolf_y@gmx.de: 5501 → 5837
# Updated anna-stelle85@web.de: 5502 → 5838
# Updated gerd-lorbeer@gmx.de: 5503 → 5839
# Updated mickey97@web.de: 5504 → 5840
# Updated ivyleaf@web.de: 5505 → 5841
# Updated karoutasgeorgi@googlemail.com: 5506 → 5842
# Updated kliebisch_dennis29@yahoo.de: 5507 → 5843
# Updated c.vornberger@icloud.com: 5508 → 5844
# Updated office@martinreinke.net: 5509 → 5845
# Updated corsair_ml@web.de: 5510 → 5846
# Updated monistreu72@t-online.de: 5511 → 5847
# Updated hooijer-jet@hotmail.nl: 5512 → 5848
# Updated schmidt-milda@gmx.de: 5513 → 5849
# Updated schmid.ch@gmx.net: 5514 → 5850
# Updated piotr.kurzaj@gmail.com: 5515 → 5851
# Updated julia.goldscheid@gmx.de: 5516 → 5852
# Updated nanok@gmx.net: 5517 → 5853
# Updated bianca_enders1989@yahoo.de: 5518 → 5854
# Updated hiller.nadine@gmx.de: 5519 → 5855
# Updated tjarkweise@web.de: 5520 → 5856
# Updated julia-rump@gmx.de: 5521 → 5857
# Updated warum345@gmail.com: 5522 → 5858
# Updated murat-bayram-web@web.de: 5523 → 5859
# Updated ilonavoelz@gmail.com: 5524 → 5860
# Updated yvonneschmidt982@gmail.com: 5525 → 5861
# Updated ddronia@web.de: 5526 → 5862
# Updated amb.sneakerfiend@googlemail.com: 5527 → 5863
# Updated rebekka.groene@web.de: 5528 → 5865
# Updated veit.giese@gmx.de: 5529 → 5866
# Updated frank.wlassak@t-online.de: 5530 → 5867
# Updated 666golem666@gmail.com: 5531 → 5868
# Updated rebecca.boedder@gmx.de: 5532 → 5869
# Updated elkeklein.1965@gmail.com: 5533 → 5870
# Updated meiko.hellenkamp@gmail.com: 5534 → 5871
# Updated gerhard.klaus@kabelmail.de: 5535 → 5872
# Updated robertengelschalk@web.de: 5536 → 5873
# Updated meli-fetz@web.de: 5537 → 5874
# Updated mario.jaeger@siemens.com: 5538 → 7460
# Updated melif@gmx.de: 5539 → 5876
# Updated saraibelana@gmail.com: 5540 → 5877
# Updated katharina101@gmx.de: 5541 → 5878
# Updated danicarieb@web.de: 5542 → 5879
# Updated autokauf64@web.de: 5543 → 5880
# Updated philipp.bauer1@web.de: 5544 → 5881
# Updated matthes_85@web.de: 5545 → 5882
# Updated anwas1@gmx.de: 5546 → 5883
# Updated daniela.strotmann@gmx.net: 5547 → 5884
# Updated mareen_soelter@gmx.de: 5548 → 5885
# Updated carolin-nadler@gmx.de: 5549 → 5886
# Updated matthias_heizmann@yahoo.com: 5550 → 5887
# Updated tickel-bjoern@web.de: 5551 → 5888
# Updated schirmer.christine@gmx.de: 5552 → 5889
# Updated rm-neu@web.de: 5553 → 5890
# Updated andreapenzo@fastwebnet.it: 5554 → 5891
# Updated upraetorius@web.de: 5555 → 5892
# Updated tina.giesecke@gmx.net: 5556 → 5893
# Updated vost924@googlemail.com: 5557 → 5894
# Updated benjamin.marquart@googlemail.com: 5558 → 5895
# Updated mail@thomaslanger.net: 5559 → 5896
# Updated hedisonntag@yahoo.de: 5560 → 5897
# Updated akracht5188@gmx.de: 5561 → 5898
# Updated jmiethe@web.de: 5562 → 5899
# Updated svenjamanka@icloud.com: 5563 → 5900
# Updated christina.mohr@gmx.net: 5564 → 5901
# Updated beababy01@outlook.hu: 5565 → 5902
# Updated anke.bertholdt@elkb.de: 5566 → 5903
# Updated c.bolte@leer.creditreform.de: 5567 → 5904
# Updated reni_manz@web.de: 5568 → 5905
# Updated dori-d@t-online.de: 5569 → 5906
# Updated veronika.rehak@gmx.at: 5570 → 5907
# Updated philipp_lukas_maurer@web.de: 5571 → 5908
# Updated d.strahn@gmx.de: 5572 → 5909
# Updated marc_deutzmann@web.de: 5573 → 5910
# Updated krissi77@hotmail.de: 5574 → 5911
# Updated daniela.michelsen@web.de: 5575 → 5912
# Updated tobias.schoo@freenet.de: 5576 → 5913
# Updated lungerich@workstation-pro.com: 5577 → 5914
# Updated clemens_kantor@yahoo.de: 5578 → 5915
# Updated annette_schwartze@hotmail.com: 5579 → 5916
# Updated stefan@sofariu.de: 5580 → 5917
# Updated marion-krebrucker@t-online.de: 5581 → 5918
# Updated eckardt@tu-berlin.de: 5582 → 5919
# Updated svdr@web.de: 5583 → 5920
# Updated gernot.jendrusch@rub.de: 5584 → 5921
# Updated panagiotis.adamidis@web.de: 5585 → 5922
# Updated chalupi@seznam.cz: 5586 → 5923
# Updated bmatthias1@msn.com: 5587 → 5924
# Updated rogerfischer1@bluewin.ch: 5588 → 5925
# Updated chr_muell@hotmail.com: 5589 → 5926
# Updated dstarch@gmx.de: 5590 → 5936
# Updated lareju@t-online.de: 5591 → 5928
# Updated stinakrebs79@googlemail.com: 5592 → 5929
# Updated lhasenkamp@aol.com: 5593 → 5930
# Updated inga.hass@gmx.de: 5594 → 5931
# Updated ju-chan9854@web.de: 5595 → 5932
# Updated anton.simon@hotmail.com: 5596 → 5933
# Updated edmund.bauch@gmx.de: 5597 → 5934
# Updated dan.nussbaum@me.com: 5598 → 5935
# Updated marc-leonard-schaefer@web.de: 5599 → 5937
# Updated marc-leonard-schaefer@gmx.de: 5600 → 5938
# Updated familie.rhauck@googlemail.com: 5601 → 5940
# Updated schlumpf1985@gmx.net: 5602 → 5941
# Updated atropal@web.de: 5603 → 5942
# Updated amochez@aol.de: 5604 → 5943
# Updated karin.singer@linznet.at: 5605 → 5944
# Updated staats.arno@gmail.com: 5606 → 5945
# Updated chantal.nock@gmail.com: 5607 → 5946
# Updated jp2206@icloud.com: 5608 → 5947
# Updated berger_nicole@gmx.net: 5609 → 5948
# Updated wittich-andri@t-online.de: 5610 → 5949
# Updated thomas_gnann@web.de: 5611 → 5951
# Updated lisa@hamakubu.de: 5612 → 5952
# Updated tobias.noetzel@gmx.de: 5613 → 5953
# Updated barbara.lampe@gmx.de: 5614 → 5956
# Updated schirmchen-@gmx.de: 5615 → 5957
# Updated stefaniejakob@web.de: 5616 → 5958
# Updated thom_stam@yahoo.com: 5617 → 5959
# Updated malte.ffm@googlemail.com: 5618 → 5960
# Updated cindy.sex@web.de: 5619 → 5961
# Updated larissa.kampfmann@gmx.de: 5620 → 5962
# Updated k.beitlich@bgw-steuerberater.de: 5621 → 5963
# Updated populous79@gmx.de: 5622 → 5964
# Updated frankvanderhoeven@hotmail.com: 5623 → 5965
# Updated n.knieling@t-online.de: 5624 → 5966
# Updated derpferd1@web.de: 5625 → 5967
# Updated p.schierz@web.de: 5626 → 5968
# Updated t_franz@t-online.de: 5627 → 5969
# Updated engraved1@aol.com: 5628 → 5970
# Updated aq42@posteo.net: 5629 → 5971
# Updated fraeuleinwagner@web.de: 5630 → 5972
# Updated lisawagner93@gmx.de: 5631 → 5973
# Updated vanessaspecht0@gmail.com: 5632 → 5975
# Updated mlandw@web.de: 5633 → 5976
# Updated greifenritter@mysticforest.de: 5634 → 5977
# Updated tomhuth2003@yahoo.de: 5635 → 9397
# Updated mafiosi_1988@hotmail.de: 5636 → 5979
# Updated marinawuellner@hotmail.com: 5637 → 5980
# Updated sandra.hambloch@googlemail.com: 5638 → 5981
# Updated martin@holm-morgen.de: 5639 → 5982
# Updated luciani.stefano@hotmail.com: 5640 → 5983
# Updated webmaster@davep.de: 5641 → 5984
# Updated martina.kraemer1@gmx.de: 5642 → 5985
# Updated dr.christian.kemmer@gmail.com: 5643 → 5986
# Updated annemueller.m@gmail.com: 5644 → 5987
# Updated f.schriewersmann@gmail.com: 5645 → 5988
# Updated lauraronge1@icloud.com: 5646 → 5989
# Updated a.ploesch-michael@web.de: 5647 → 5990
# Updated michael.hanelt@gmail.com: 5648 → 7379
# Updated jonas.furler@eblcom.ch: 5649 → 5992
# Updated a77ra@libero.it: 5650 → 5993
# Updated bjoern.feldkamp@gmx.de: 5651 → 5994
# Updated a.borresch@gmx.de: 5652 → 5995
# Updated jan.busack@gmail.com: 5653 → 5996
# Updated n.huber243@gmail.com: 5654 → 5998
# Updated christianballerstedt@gmx.de: 5655 → 5999
# Updated cecile.schaefer@gmx.de: 5656 → 6000
# Updated ck.fuchs@gmx.de: 5657 → 6001
# Updated andrea.hermansdorfer@googlemail.com: 5658 → 6002
# Updated hort-70.grundschule@dresden.de: 5659 → 6003
# Updated fiedler-s@gmx.de: 5660 → 6004
# Updated ka-ro@hotmail.de: 5661 → 6006
# Updated blechruab@web.de: 5662 → 6007
# Updated bettina_roesch@web.de: 5663 → 6008
# Updated t.suttmann@gmx.de: 5664 → 6009
# Updated asurmen7@gmail.com: 5665 → 6010
# Updated corinna.schorradt@web.de: 5666 → 6011
# Updated jana.neuland@gmx.de: 5667 → 6012
# Updated marlet.euchler@googlemail.com: 5668 → 6013
# Updated nico.sagewka25@gmail.com: 5669 → 6014
# Updated d.enzler@t-online.de: 5670 → 6015
# Updated angela_behrendt@web.de: 5671 → 6016
# Updated dianasprung@hotmail.de: 5672 → 6017
# Updated sarahlenzen@hotmail.de: 5673 → 6018
# Updated faflo99@t-online.de: 5674 → 6019
# Updated kleinedasy@freenet.de: 5675 → 6020
# Updated janis.kalvins@gmail.com: 5676 → 6021
# Updated wahsner@arcor.de: 5677 → 6022
# Updated mayer-katrin@gmx.net: 5678 → 6023
# Updated kirstin.wall@gmx.de: 5679 → 6024
# Updated julia.morgenstern@live.de: 5680 → 6025
# Updated sushi@vonet.lu: 5681 → 6026
# Updated sophie_joel@pt.lu: 5682 → 6027
# Updated marion_heuser@t-online.de: 5683 → 6028
# Updated maychristina@gmx.de: 5684 → 6029
# Updated m.martharis@gmx.de: 5685 → 6030
# Updated lulu_aver@yahoo.de: 5686 → 6031
# Updated lady-glencoe@gmx.de: 5687 → 6032
# Updated finkjulia@hotmail.de: 5688 → 6033
# Updated loew89@googlemail.com: 5689 → 6034
# Updated nadine-neidl@t-online.de: 5690 → 6035
# Updated verena_lothes@yahoo.de: 5691 → 6036
# Updated julia.rasch@gmx.de: 5692 → 6037
# Updated canim_dg@hotmail.de: 5693 → 6038
# Updated sen.grebenstein@gmail.com: 5694 → 6039
# Updated franziska.niklas@gmx.net: 5695 → 6040
# Updated sanne-keller@web.de: 5696 → 6054
# Updated bettina.wolter@aol.com: 5697 → 6622
# Updated daniel.oleinik@gmail.com: 5698 → 6043
# Updated manne.89.ml@gmail.com: 5699 → 6044
# Updated lil_layla222@hotmail.com: 5700 → 6045
# Updated michaela.gabler@web.de: 5701 → 6046
# Updated kramer_ricarda@yahoo.de: 5702 → 6047
# Updated yosser0504@gmail.com: 5703 → 6049
# Updated sonjajanssen@outlook.com: 5704 → 6050
# Updated kati_hellwig@web.de: 5705 → 6051
# Updated sabines1984@web.de: 5706 → 6052
# Updated stefan.doebelt@web.de: 5707 → 6053
# Updated gerald.rades@web.de: 5708 → 6055
# Updated michaela.blumrich@gmx.at: 5709 → 6056
# Updated isabellageiger@gmx.de: 5710 → 6057
# Updated msewing@web.de: 5711 → 6058
# Updated mirjampumm@gmail.com: 5712 → 6059
# Updated susanne070361@gmx.de: 5713 → 6060
# Updated volker.grauel@web.de: 5714 → 6061
# Updated lea.mai@naehnet.de: 5715 → 6062
# Updated chr.koenig84@gmx.de: 5716 → 6063
# Updated max20lax@yahoo.com: 5717 → 6064
# Updated jens.email@web.de: 5718 → 6065
# Updated chris.denk@freenet.de: 5719 → 6066
# Updated a.holtkotten@web.de: 5720 → 6067
# Updated gehrke.catharina@gmail.com: 5721 → 6068
# Updated christian-starke87@gmx.de: 5722 → 6070
# Updated timo.hewer@gmail.com: 5723 → 6071
# Updated fuer_tani@web.de: 5724 → 6072
# Updated tobias_keller@gmx.net: 5725 → 6073
# Updated maydaselin89@gmail.com: 5726 → 6074
# Updated born-laudenbach@t-online.de: 5727 → 6075
# Updated tobi1287@web.de: 5728 → 6076
# Updated thomas.wilkens@ewe.net: 5729 → 6077
# Updated ingo.rieck@t-online.de: 5730 → 6078
# Updated katja.szonn@gmail.com: 5731 → 6079
# Updated d.grill@gmx.net: 5732 → 6080
# Updated gabriele.vollbrecht@web.de: 5733 → 6081
# Updated r.hofer@tsn.at: 5734 → 6082
# Updated k-g-mueller@gmx.de: 5735 → 6083
# Updated sandra.bachhofer@gmx.de: 5736 → 6084
# Updated m.schmidt@nskom.de: 5737 → 6085
# Updated stelke@osnanet.de: 5738 → 6086
# Updated misstakes@gmx.de: 5739 → 6087
# Updated julibaumgarten@googlemail.com: 5740 → 6088
# Updated dagmar.ristenbieter@gmail.com: 5741 → 6089
# Updated dagmar.ristenbieter@googlemail.com: 5742 → 6090
# Updated bernadetahauprich@gmail.com: 5743 → 6091
# Updated mika-sun@web.de: 5744 → 6092
# Updated frederikmack@hotmail.com: 5745 → 6093
# Updated katjahelwig@gmx.de: 5746 → 6094
# Updated joelgangolf@hotmail.com: 5747 → 7363
# Updated jens_quinkenstein@web.de: 5748 → 6096
# Updated dominik.offenwager@gmail.com: 5749 → 6097
# Updated barbarajacobi@t-online.de: 5750 → 6098
# Updated stricker.angela@web.de: 5751 → 6099
# Updated danielbleher@gmx.de: 5752 → 6100
# Updated brohel@web.de: 5753 → 6101
# Updated simonruehl@gmx.de: 5754 → 6102
# Updated web.stb@web.de: 5755 → 6103
# Updated julianszasz@gmail.com: 5756 → 6104
# Updated christianedrees@gmail.com: 5757 → 6105
# Updated sebastian.furth@gmail.com: 5758 → 6107
# Updated stefanie.kretzer@yahoo.de: 5759 → 6108
# Updated johannes.ley@gmx.de: 5760 → 6109
# Updated christian.hartmann@gmx.info: 5761 → 6110
# Updated katharinaoeing@gmx.de: 5762 → 6111
# Updated d.beier67@googlemail.com: 5763 → 6112
# Updated gabrielkrippel2006@gmail.com: 5764 → 6113
# Updated gesundheit08mammutbaum@icloud.com: 5765 → 6114
# Updated drmboettger@aol.com: 5766 → 6117
# Updated uta.herold.1959@gmail.com: 5767 → 6118
# Updated hermann_raible@hotmail.com: 5768 → 6119
# Updated bestellung@winkler-rd.de: 5769 → 6120
# Updated mail@holgersorg.de: 5770 → 6121
# Updated michael.volksdorf@gmx.de: 5771 → 6122
# Updated gsmijne@gmail.com: 5772 → 6123
# Updated vanessa82@gmx.de: 5773 → 6124
# Updated nadiawalther@gmx.de: 5774 → 6125
# Updated steffihopf@gmail.com: 5775 → 6126
# Updated pd@philippduering.com: 5776 → 6127
# Updated ni.ja.pe@gmx.de: 5777 → 6128
# Updated karin.tenbusch@freenet.de: 5778 → 6130
# Updated elisabeth.huber3@gmx.at: 5779 → 6131
# Updated dennis-schroeder90@web.de: 5780 → 6132
# Updated manuela.j@t-online.de: 5781 → 6133
# Updated wohommers@arcor.de: 5782 → 6134
# Updated s-funk@gmx.net: 5783 → 6135
# Updated betty_dirks@yahoo.com: 5784 → 6136
# Updated roland.thumann@gmx.de: 5785 → 6139
# Updated ma2009ra@aol.com: 5786 → 6142
# Updated klinter@gmx.de: 5787 → 6140
# Updated silence1000@googlemail.com: 5788 → 6141
# Updated maz3_san@gmx.de: 5789 → 6143
# Updated maren.boesel@gmail.com: 5790 → 6144
# Updated boenisch-j@t-online.de: 5791 → 6145
# Updated lukas96.schmidt@googlemail.com: 5792 → 6146
# Updated lechner.michl@gmx.at: 5793 → 6147
# Updated anke-wilmer@t-online.de: 5794 → 6148
# Updated miriam.runkel@gmx.de: 5795 → 6149
# Updated jonas.kunze98s@web.de: 5796 → 6150
# Updated noomi.kronenwett@gmx.net: 5797 → 6151
# Updated fam.lewi@kabelmail.de: 5798 → 6152
# Updated nathalie.bouckaert@laposte.net: 5799 → 6153
# Updated rita-kempe@web.de: 5800 → 6154
# Updated anja_baude@web.de: 5801 → 6155
# Updated d-kloiner@web.de: 5802 → 6156
# Updated d.uebelacker@web.de: 5803 → 6157
# Updated annamit4sternchen@gmx.de: 5804 → 6158
# Updated jana@kiesendahl.de: 5805 → 6159
# Updated eliasgeigle@gmx.de: 5806 → 6160
# Updated keldenich@marmucki.de: 5807 → 6162
# Updated christianebous@web.de: 5808 → 6163
# Updated franze.d@gmx.de: 5809 → 6164
# Updated scherer.elisabeth@icloud.com: 5810 → 6166
# Updated d.ferchow@freenet.de: 5811 → 6167
# Updated sinangerman@gmail.com: 5812 → 6168
# Updated christian.vierschgens@web.de: 5813 → 6169
# Updated tino_home@web.de: 5814 → 6170
# Updated robinfranz98@gmail.com: 5815 → 6171
# Updated martinnohl@web.de: 5816 → 6172
# Updated eberhard-plauen@t-online.de: 5817 → 6173
# Updated thomasmoritz89@yahoo.de: 5818 → 6174
# Updated cynthia.staud@gmx.de: 5819 → 6175
# Updated cornelia_84@web.de: 5820 → 6176
# Updated stefanmaus@gmx.de: 5821 → 6177
# Updated anne.auert@yahoo.de: 5822 → 6178
# Updated p.lorenz43@gmail.com: 5823 → 6179
# Updated peter.kampfmueller@oebv.com: 5824 → 6180
# Updated stepakova@yandex.ru: 5825 → 6181
# Updated nicolas_frevert@web.de: 5826 → 6182
# Updated mariosollenau29@gmail.com: 5827 → 6183
# Updated timo.weber@ymail.com: 5828 → 6184
# Updated eva@edelramsch.de: 5829 → 6185
# Updated rensing@netcologne.de: 5830 → 6187
# Updated kmontwe@t-online.de: 5831 → 6188
# Updated philip.ortner@web.de: 5832 → 6189
# Updated charlottgasda@web.de: 5833 → 6190
# Updated carina.mueller@mufi-world.de: 5834 → 6191
# Updated miguelbenitez@outlook.de: 5835 → 6192
# Updated martin_zwingmann@web.de: 5836 → 6193
# Updated christina.altenberger@gmx.de: 5837 → 6194
# Updated post.antje.pollex@gmail.com: 5838 → 6195
# Updated bernhard.jungmeir@gmail.com: 5839 → 6196
# Updated christina.doerrbaum@t-online.de: 5840 → 6197
# Updated a_schroeder_94@web.de: 5841 → 6198
# Updated gabrieleuhland@t-online.de: 5842 → 6199
# Updated ilona-martens@t-online.de: 5843 → 6200
# Updated nadiner201@gmail.com: 5844 → 6201
# Updated nilsrumm@gmail.com: 5845 → 6202
# Updated vadim.bitschinski@web.de: 5846 → 6203
# Updated ellenehret3496@gmail.com: 5847 → 6204
# Updated kristin.schwarz23@googlemail.com: 5848 → 6534
# Updated dr.milutinovic@web.de: 5849 → 6206
# Updated nadinealthoff@gmx.de: 5850 → 6207
# Updated sandra.woermann@web.de: 5851 → 6208
# Updated thomas_bernhard@web.de: 5852 → 6209
# Updated adoberauer@t-online.de: 5853 → 6210
# Updated sindy.auerbach@web.de: 5854 → 6212
# Updated stefanie-stocker@web.de: 5855 → 6213
# Updated mar.fischer@mail.de: 5856 → 6214
# Updated rpwilliams@hotmail.de: 5857 → 6215
# Updated e.rakowitz@gmx.de: 5858 → 6216
# Updated go2sellef@aol.com: 5859 → 6217
# Updated maren.paulmann@bund-rlp.de: 5860 → 6218
# Updated karpinski-2206@web.de: 5861 → 6219
# Updated helga.knickel58@gmail.com: 5862 → 6220
# Updated volk-edingen-neckarhausen@t-online.de: 5863 → 6221
# Updated lukas-thieme1@live.de: 5864 → 6222
# Updated sophieroebel@icloud.com: 5865 → 6223
# Updated amelie.roy59@gmail.com: 5866 → 6224
# Updated mmartineznegro@gmail.com: 5867 → 6225
# Updated jasminn1978@aol.com: 5868 → 6226
# Updated hoeschf@aol.com: 5869 → 6227
# Updated wiebke.borcherding@t-online.de: 5870 → 6228
# Updated bocor83@yahoo.com: 5871 → 6229
# Updated v-bloemen@t-online.de: 5872 → 6230
# Updated luver12@hotmail.de: 5873 → 6231
# Updated ginamuebackermann@web.de: 5874 → 6232
# Updated steffi.03@freenet.de: 5875 → 6233
# Updated bmeier1977@gmail.com: 5876 → 6235
# Updated gabi.wagner@salzburg-begreifen.at: 5877 → 6236
# Updated d.graeb@gmx.de: 5878 → 6237
# Updated daniel.stierhof@gmx.de: 5879 → 6238
# Updated carolabittner@gmx.de: 5880 → 6239
# Updated reinermura@gmail.com: 5881 → 6240
# Updated susi_heisig@web.de: 5882 → 6289
# Updated miamarmelade270@gmail.com: 5883 → 6242
# Updated nambli@unitybox.de: 5884 → 6243
# Updated heinz-peter.meyer@ewetel.net: 5885 → 6244
# Updated joni.wyso@mail.de: 5886 → 6245
# Updated frank@hoenl.net: 5887 → 6246
# Updated max.dummler@gmx.de: 5888 → 6247
# Updated mandea@lenzu.de: 5889 → 6248
# Updated uweklauk@t-online.de: 5890 → 9052
# Updated f.kuepker@freenet.de: 5891 → 6250
# Updated meik.peters@gmx.de: 5892 → 6251
# Updated s.cludass@gmx.net: 5893 → 6252
# Updated susannekuebler@gmx.de: 5894 → 6288
# Updated k.koger@gmx.at: 5895 → 6255
# Updated sjorde@ibj-mq.de: 5896 → 6256
# Updated holtz.christian@icloud.com: 5897 → 6257
# Updated toxic_ivy@hotmail.de: 5898 → 6258
# Updated karsten.knappe@arcor.de: 5899 → 6259
# Updated denise.leffs@gmx.de: 5900 → 6260
# Updated dtmueller@gmx.de: 5901 → 6261
# Updated grisufeuerwehr@gmx.net: 5902 → 6262
# Updated b.klein.ga@gmail.com: 5903 → 6263
# Updated andi.kriegel@gmx.de: 5904 → 6264
# Updated marcus.gruehn@gmx.de: 5905 → 6265
# Updated jessi300591@gmail.com: 5906 → 6266
# Updated juergen.annelie@web.de: 5907 → 6267
# Updated foo-mandea.de@paukner.cc: 5908 → 6268
# Updated christian.boegl@googlemail.com: 5909 → 6269
# Updated friedi82@gmx.de: 5910 → 6270
# Updated christiane.schnell@online.de: 5911 → 6271
# Updated familie@creabeads.ch: 5912 → 6272
# Updated jladerick@t-online.de: 5913 → 6273
# Updated ch_broeker@gmx.de: 5914 → 6274
# Updated christopher-schmid@live.de: 5915 → 6275
# Updated ira.d@web.de: 5916 → 6276
# Updated nicolailorenzhelberg@gmail.com: 5917 → 6277
# Updated nico-helberg@web.de: 5918 → 6278
# Updated elisabeth.ganzlin@mail.de: 5919 → 6279
# Updated sandra.stein90@gmx.net: 5920 → 6280
# Updated sutthoff@gmx.de: 5921 → 6281
# Updated chrishoffi405@web.de: 5922 → 6282
# Updated bella_ge@web.de: 5923 → 6883
# Updated hausperger.manfred@gmail.com: 5924 → 6284
# Updated kirsten.bartussek@gmx.net: 5925 → 6285
# Updated k.weinert@gmx.de: 5926 → 6287
# Updated maria_alex@web.de: 5927 → 6290
# Updated familie-neuhofer@web.de: 5928 → 6291
# Updated matthias@fam-link-bgt.de: 5929 → 6292
# Updated ccstickel@web.de: 5930 → 6293
# Updated chrissi_dominik@yahoo.de: 5931 → 6294
# Updated alisabritz@gmx.net: 5932 → 6295
# Updated andre.py@web.de: 5933 → 6296
# Updated jg211221@aol.com: 5934 → 6297
# Updated filippo.gratzl@gmail.com: 5935 → 6298
# Updated ricardadeutschmann@web.de: 5936 → 6299
# Updated lieber_christian@web.de: 5937 → 6300
# Updated d.gehlhaus@gmx.net: 5938 → 6301
# Updated olga@neumann-projekte.de: 5939 → 6302
# Updated anjaneuberger@aol.com: 5940 → 6303
# Updated mohrli@gmx.de: 5941 → 6304
# Updated nershad@gmx.de: 5942 → 6305
# Updated nicolebruns89@yahoo.de: 5943 → 6306
# Updated selimanu.ms@gmail.com: 5944 → 6307
# Updated k.gebhardt@htp-tel.de: 5945 → 6308
# Updated katharinaosterwald@gmail.com: 5946 → 6309
# Updated anna_walter@gmx.at: 5947 → 6313
# Updated christine-kessler@gmx.net: 5948 → 6311
# Updated j-froeschle@gmx.de: 5949 → 6369
# Updated kfritzsch72@web.de: 5950 → 6314
# Updated beatrice.rueger@gmx.de: 5951 → 6315
# Updated flemstar3000@web.de: 5952 → 6316
# Updated romina.reck@gmx.de: 5953 → 6317
# Updated peppedierckx@telenet.be: 5954 → 6318
# Updated jung.stefanie@me.com: 5955 → 6319
# Updated solveig_work@live.de: 5956 → 6320
# Updated crazyroberto@msn.com: 5957 → 6321
# Updated isabell.schwertle@googlemail.com: 5958 → 6323
# Updated hitti.co@t-online.de: 5959 → 6324
# Updated kfbliss@gmail.com: 5960 → 6325
# Updated gerhardt.christian@gmx.de: 5961 → 6326
# Updated s.fakler@t-online.de: 5962 → 6327
# Updated michaelklausmann@t-online.de: 5963 → 6328
# Updated siwatrim@web.de: 5964 → 6329
# Updated marei.raming@gmx.de: 5965 → 6330
# Updated angela.roehrig@gmx.de: 5966 → 6331
# Updated jan.bolhoefer@t-online.de: 5967 → 6332
# Updated sabine_kontny@t-online.de: 5968 → 6333
# Updated matthias.hopstock@web.de: 5969 → 6334
# Updated sailletc@hotmail.com: 5970 → 6335
# Updated habermehl.d@t-online.de: 5971 → 6337
# Updated stella.mahnkopf@htp-tel.de: 5972 → 6338
# Updated alternate01@gmx.de: 5973 → 6339
# Updated maholthaus@gmx.de: 5974 → 6340
# Updated fritz.romy@gmx.net: 5975 → 6341
# Updated albers_ag@web.de: 5976 → 6342
# Updated safricke.koeln@gmail.com: 5977 → 6343
# Updated castroy@free.fr: 5978 → 6344
# Updated kontakt@schnitzler-berg.de: 5979 → 6345
# Updated daniel.koennyue@me.com: 5980 → 6346
# Updated daniwl.koennyue@me.com: 5981 → 6347
# Updated sudestadasounds@gmail.com: 5982 → 6348
# Updated maren_freisen@hotmail.com: 5983 → 6349
# Updated papajazz@gmx.de: 5984 → 6350
# Updated nora.wieling@posteo.de: 5985 → 6351
# Updated kirsten_schroeter@web.de: 5986 → 6352
# Updated a.zschornack@yahoo.de: 5987 → 6353
# Updated birgit.zacher83@gmx.de: 5988 → 6354
# Updated alexander93057@gmail.com: 5989 → 6355
# Updated cathrin.haina@gmx.de: 5990 → 6356
# Updated noralf@t-online.de: 5991 → 6357
# Updated mt@das-weingut.com: 5992 → 6358
# Updated lisamueller-1992@web.de: 5993 → 6359
# Updated tantechupi@bluewin.ch: 5994 → 6360
# Updated abcdfamily618184@aol.com: 5995 → 6361
# Updated belinda.skoppek@gmx.de: 5996 → 6362
# ...
# Updated aj_vandebeek@hotmail.com: 9522 → 10100
# Updated d.riegers@t-online.de: 9523 → 10101
# Updated mandymauritz94@gmail.com: 9524 → 10102
# Updated isabelle.steffen@web.de: 9525 → 10104
# Updated michellejakob@hotmail.com: 9526 → 10105
# Updated dino@depple.de: 9527 → 10106
# Updated lille1944@hotmail.com: 9528 → 10108
# Updated daniel.hiller@gmx.at: 9529 → 10109
# Updated s.gaa@gmx.net: 9530 → 10110
# Updated pascal.hagner@gmail.com: 9531 → 10111
# Updated pascal_hagner@gmx.de: 9532 → 10112
# Updated nagelmarion@hotmail.com: 9533 → 10113
# Updated christian_achimov@yahoo.de: 9534 → 10114
# Updated clauswilson@gmail.com: 9535 → 10115
# Updated ahrenserei@googlemail.com: 9536 → 10116
# Updated utanorang@gmail.com: 9537 → 10117
# Updated sabsihergert@web.de: 9538 → 10118
# Updated regina.faller@web.de: 9539 → 10119
# Updated sabine.s.andersen@gmail.com: 9540 → 10120
# Updated antonio.marto@icloud.com: 9541 → 10121
# Updated tiffy1981@gmx.net: 9542 → 10122
# Updated strobel.kathrin@googlemail.com: 9543 → 10123
# Updated katyreiner@aol.de: 9544 → 10124
# Updated i_drechsler@web.de: 9545 → 10125
# Updated fabsl80@gmx.de: 9546 → 10126
# Updated katharina@bassler-online.de: 9547 → 10127
# Updated martina.metz@gmx.de: 9548 → 10128
# Updated lodne_egern@hotmail.com: 9549 → 10129
# Updated uhl-heiztechnik@email.de: 9550 → 10130
# Updated karinsbriefkasten@web.de: 9551 → 10131
# Updated ramonamarks@web.de: 9552 → 10132
# Updated ion10.07.1976@gmail.com: 9553 → 10133
# Updated tuff-gong@web.de: 9554 → 10134
# Updated jana-kurz@web.de: 9555 → 10135
# Updated schunnimaster@gmx.de: 9556 → 10137
# Updated maikehoffmann71@gmail.com: 9557 → 10138
# Updated marina.d79@web.de: 9558 → 10139
# Updated tilman-bauer@gmx.de: 9559 → 10140
# Updated theresa-biermann@web.de: 9560 → 10141
# Updated u.knorr-einfachsein@posteo.de: 9561 → 10142
# Updated vivien.bartlau@yahoo.de: 9562 → 10143
# Updated ch.steinlehner@gmail.com: 9563 → 10144
# Updated vtrenkenschuh@yahoo.de: 9564 → 10145
# Updated smatzkeit@web.de: 9565 → 10146
# Updated matteo_pastore@hotmail.de: 9566 → 10147
# Updated gizeh1989@gmx.net: 9567 → 10148
# Updated hoburg@gmx.de: 9568 → 10149
# Updated sophiethiele1@gmx.de: 9569 → 10150
# Updated nina.darga@gmx.net: 9570 → 10151
# Updated dominik.schloms@osnanet.de: 9571 → 10152
# Updated daniel.zerbst@gmx.de: 9572 → 10153
# Updated heid.michaela@gmx.net: 9573 → 10154
# Updated jasmin.potthoff@web.de: 9574 → 10155
# Updated natalie1909@web.de: 9575 → 10157
# Updated unimax.hd@gmail.com: 9576 → 10158
# Updated wynsdanny@web.de: 9577 → 10159
# Updated eugen.strobel@gmx.net: 9578 → 10165
# Updated jessicamuller720@gmail.com: 9579 → 10161
# Updated christian95pfeiffer@yahoo.de: 9580 → 10162
# Updated gilbert@zangerle.lu: 9581 → 10174
# Updated maxi_nebel@hotmail.com: 9582 → 10164
# Updated g.selzer@onlinehome.de: 9583 → 10166
# Updated erichheilscher@gmail.com: 9584 → 10167
# Updated kaffee1704@gmail.com: 9585 → 10168
# Updated manuelaweyer1704@gmail.com: 9586 → 10169
# Updated sdaeuwel@gmx.de: 9587 → 10170
# Updated gohem@me.com: 9588 → 10171
# Updated steffen.juettner@gmx.de: 9589 → 10172
# Updated michael@steingart.de: 9590 → 10173
# Updated janineribeiro@gmx.net: 9591 → 10175
# Updated roland.maringer@t-online.de: 9592 → 10176
# Updated astridfelderer@hotmail.com: 9593 → 10177
# Updated anna.porubenski@web.de: 9594 → 10178
# Updated magdalenafronda@ymail.com: 9595 → 10179
# Updated joachimhertle@web.de: 9596 → 10180
# Updated dirk_haubrich@yahoo.com: 9597 → 10181
# Updated katharina_korte1984@yahoo.de: 9598 → 10182
# Updated schloderer.melanie@web.de: 9599 → 10183
# Updated iriogbe@aol.com: 9600 → 10184
# Updated fam.hilbig@yahoo.de: 9601 → 10185
# Updated justus-manthey@web.de: 9602 → 10186
# Updated annika.vanhar@gmail.com: 9603 → 10187
# Updated stefanredel5@gmail.com: 9604 → 10188
# Updated hdbuerger@web.de: 9605 → 10189
# Updated juliaseif@web.de: 9606 → 10190
# Updated laven_gedicht0@icloud.com: 9607 → 10191
# Updated steffenpeters3791@gmx.de: 9608 → 10192
# Updated alexander@steinhoefer.net: 9609 → 10193
# Updated erkanulgen@hotmail.com: 9610 → 10194
# Updated i.bauschke@bauschke-partner.de: 9611 → 10195
# Updated roemermelanie40@gmail.com: 9612 → 10196
# Updated andrew0815@web.de: 9613 → 10197
# Updated marleenzapf@gmx.de: 9614 → 10198
# Updated stefanie.schreyer@outlook.de: 9615 → 10199
# Updated midra@gmx.net: 9616 → 10200
# Updated knut.duentz@berlin.de: 9617 → 10201
# Updated c.bit@gmx.de: 9618 → 10202
# Updated thoma.jessica9@googlemail.com: 9619 → 10203
# Updated andrea_rm@web.de: 9620 → 10204
# Updated heinzjosefgoette@t-online.de: 9621 → 10205
# Updated c.gro@gmx.de: 9622 → 10206
# Updated marco.kammes@yahoo.de: 9623 → 10207
# Updated angelikalangner55@googlemail.com: 9624 → 10208
# Updated juergen_beate_maybaum@t-online.de: 9625 → 10209
# Updated uwtido@gmx.de: 9626 → 10211
# Updated margit.dorn@gmx.at: 9627 → 10212
# Updated slayer110@gmx.de: 9628 → 10213
# Updated leopold.meyerhofer@t-online.de: 9629 → 10214
# Updated alexander.waerthl@t-online.de: 9630 → 10215
# Updated webmaster@sebbionline.de: 9631 → 10216
# Updated b.mueck@mail.de: 9632 → 10217
# Updated kadeguho@gmail.com: 9633 → 10218
# Updated andor.krizsan@gmail.com: 9634 → 10219
# Updated jana.berndt@ymail.com: 9635 → 10220
# Updated stefan.haselbeck@gmail.com: 9636 → 10221
# Updated louiseg150@yahoo.co.uk: 9637 → 10222
# Updated denis.seebich@hartmann.info: 9638 → 10223
# Updated nikolaus.seifert@gmail.com: 9639 → 10225
# Updated m.meyer-vk@web.de: 9640 → 10226
# Updated simonau@web.de: 9641 → 10227
# Updated sven-globig@arcor.de: 9642 → 10228
# Updated jmcalvoma@gmail.com: 9643 → 10229
# Updated daniela.alton@gmail.com: 9644 → 10230
# Updated flolinden@yahoo.de: 9645 → 10231
# Updated simonbachmeier@freenet.de: 9646 → 10232
# Updated heidi-andree@t-online.de: 9647 → 10233
# Updated johannes.schartau@gmail.com: 9648 → 10234
# Updated andreas.parten@web.de: 9649 → 10235
# Updated vlatko.vidakovic@hotmail.com: 9650 → 10236
# Updated anjaweiss9@msn.com: 9651 → 10237
# Updated sascha0711@gmx.net: 9652 → 10238
# Updated franke.allgaier@gmx.dd: 9653 → 10239
# Updated hasenstab.andreas@gmx.de: 9654 → 10240
# Updated tobias@sollbruch.info: 9655 → 10241
# Updated karinwagener59@gmail.com: 9656 → 10242
# Updated michael.schroeder@kuehne-nagel.com: 9657 → 10243
# Updated jenny_voelker@gmx.de: 9658 → 10244
# Updated philipp.ziegler91@gmx.de: 9659 → 10245
# Updated klein-modell@gmx.de: 9660 → 10246
# Updated minderstmaxi@googlemail.com: 9661 → 10247
# Updated raffael.rhein@t-online.de: 9662 → 10248
# Updated patty.dah@gmx.de: 9663 → 10249
# Updated albertosanchez@live.de: 9664 → 10250
# Updated marco-grupp@web.de: 9665 → 10251
# Updated designsophy@gmail.com: 9666 → 10252
# Updated philip.steen@mail.com: 9667 → 10253
# Updated m-harder@gmx.net: 9668 → 10254
# Updated pefferkoven@t-online.de: 9669 → 10255
# Updated simone.missenberger@gmx.de: 9670 → 10256
# Updated chrarn@gmx.de: 9671 → 10257
# Updated akloth70@gmail.com: 9672 → 10258
# Updated christina.reichert@hotmail.de: 9673 → 10259
# Updated uud4711@gmx.net: 9674 → 10260
# Updated raabe.marco@web.de: 9675 → 10261
# Updated marcoseither@googlemail.com: 9676 → 10262
# Updated sevinge@yahoo.com: 9677 → 10263
# Updated eugenia.helzer-kirsch@gmx.de: 9678 → 10264
# Updated katjaschaefer17@googlemail.com: 9679 → 10265
# Updated jonhu_1973@yahoo.com: 9680 → 10267
# Updated bastian.schittkowski@live.de: 9681 → 10268
# Updated lutyanova@yandex.ru: 9682 → 10269
# Updated david_burkert@web.de: 9683 → 10270
# Updated mariabork82@gmx.de: 9684 → 10271
# Updated inesh82@web.de: 9685 → 10272
# Updated klaemmerhirt@fes-dresden.de: 9686 → 10273
# Updated roegelsperger@roeco.at: 9687 → 10274
# Updated www.sallly@gmx.de: 9688 → 10275
# Updated lukas96.schmidt+mandea@googlemail.com: 9689 → 10276
# Updated xeromex@gmail.com: 9690 → 10277
# Updated grolmusz@gmx.de: 9691 → 10278
# Updated manuel-paul@gmx.net: 9692 → 10279
# Updated ayluna@freenet.de: 9693 → 10280
# Updated jochen.hanser@gmx.com: 9694 → 10281
# Updated sabrina.rossbach@gmx.de: 9695 → 10282
# Updated yvonne_klp@gmx.de: 9696 → 10283
# Updated leoniethomas1995@gmail.com: 9697 → 10284
# Updated manu.pollak@gmail.com: 9698 → 10285
# Updated philippgehrig@gmx.de: 9699 → 10286
# Updated rebeka.frueholz@hotmail.com: 9700 → 10287
# Updated daniela-thiemicke@gmx.de: 9701 → 10288
# Updated boarderlandfiss@web.de: 9702 → 10289
# Updated martin.ulmer@web.de: 9703 → 10290
# Updated michael.falkenreck@t-online.de: 9704 → 10291
# Updated admin@xixasoft.com: 9705 → 10292
# Updated blumenmeer@t-online.de: 9706 → 10293
# Updated evert.edithvbeek@gmail.com: 9707 → 10294
# Updated rebecca.wuenschmann@web.de: 9708 → 10295
# Updated neumann_paul1@web.de: 9709 → 10296
# Updated ziegen-peter@posteo.de: 9710 → 10297
# Updated silviafreistedt@gmx.de: 9711 → 10299
# Updated fabian@giesemail.de: 9712 → 10300
# Updated sebastianamelung@gmail.com: 9713 → 10301
# Updated reinhardt-sack@web.de: 9714 → 10302
# Updated anna.roming@t-online.de: 9715 → 10303
# Updated muschick.susanne@googlemail.com: 9716 → 10304
# Updated bsra.yagci@gmail.com: 9717 → 10305
# Updated akbabah75@gmail.com: 9718 → 10306
# Updated fcmfan74@gmx.de: 9719 → 10307
# Updated glederer-ganse@mail.pcom.de: 9720 → 10308
# Updated arualster@gmx.de: 9721 → 10309
# Updated kdienst@gmx.de: 9722 → 10310
# Updated besson.pascal88@gmail.com: 9723 → 10311
# Updated anita.bau@hotmail.de: 9724 → 10312
# Updated jogeschwend@icloud.com: 9725 → 10313
# Updated ginettekoekenhoff@icloud.com: 9726 → 10314
# Updated riana.rinck@googlemail.com: 9727 → 10315
# Updated l.fuchs26@gmail.com: 9728 → 10316
# Updated niclas.piehl7250@gmail.com: 9729 → 10317
# Updated irene.anderl@t-online.de: 9730 → 10318
# Updated locki_87@yahoo.de: 9731 → 10319
# Updated klaus.ruettnauer@outlook.com: 9732 → 10320
# Updated nds.030795@gmail.com: 9733 → 10321
# Updated warda74@gmx.de: 9734 → 10322
# Updated donner.christopher@gmx.de: 9735 → 10323
# Updated thaboberg@hormail.com: 9736 → 10324
# Updated thieswinkelaar@hotmail.com: 9737 → 10325
# Updated c.nee1988@gmail.com: 9738 → 10326
# Updated ries-atzi@t-online.de: 9739 → 10327
# Updated nina.scharf1993@gmx.de: 9740 → 10328
# Updated gmauro987@gmail.com: 9741 → 10329
# Updated indien90@web.de: 9742 → 10330
# Updated tobiasburkert31@gmail.com: 9743 → 10331
# Updated teddy4711@web.de: 9744 → 10332
# Updated lisalottek@web.de: 9745 → 10333
# Updated wolfgang.lott@aol.de: 9746 → 10334
# Updated regina.leidenfrost@gmx.at: 9747 → 10353
# Updated katja.frustaci@t-online.de: 9748 → 10336
# Updated diverberare@gmx.de: 9749 → 10337
# Updated blondi19031992@yahoo.de: 9750 → 10338
# Updated renerohdeberlin@yahoo.de: 9751 → 10339
# Updated julekastl@gmail.com: 9752 → 10340
# Updated dg4ygi@web.de: 9753 → 10342
# Updated tim.kalmey@posteo.de: 9754 → 10343
# Updated tibrehm@me.com: 9755 → 10344
# Updated vivien.gries@gmx.de: 9756 → 10345
# Updated franziska_schoeberlein@t-online.de: 9757 → 10346
# Updated moritz.heitmueller@gmx.de: 9758 → 10347
# Updated j.dirnhoefer@yahoo.de: 9759 → 10348
# Updated lea.wormann@yahoo.de: 9760 → 10349
# Updated steffi.koesters@gmx.de: 9761 → 10350
# Updated inge-ignatzek@t-online.de: 9762 → 10351
# Updated hanisch-ines@web.de: 9763 → 10352
# Updated webmaster@etk-online.de: 9764 → 10354
# Updated steffenmohr82@gmail.com: 9765 → 10355
# Updated behrendt-elke@gmx.de: 9766 → 10356
# Updated tockatess@gmx.net: 9767 → 10357
# Updated hannahschlecht@web.de: 9768 → 10358
# Updated asma.asif2007@gmail.com: 9769 → 10359
# Updated simon.oehrlein@web.de: 9770 → 10360
# Updated dr.kerstinthoma@yahoo.de: 9771 → 10361
# Updated nicoleselle@gmx.net: 9772 → 10362
# Updated klein.uschi@gmail.com: 9773 → 10364
# Updated ginko@gmx.li: 9774 → 10365
# Updated bartzsilbach@web.de: 9775 → 10366
# Updated g.mike@gmx.net: 9776 → 10367
# Updated ines.schwabe@freenet.de: 9777 → 10368
# Updated stratmann-ulmer@freenet.de: 9778 → 10369
# Updated nidon@gmx.de: 9779 → 10370
# Updated christoph.geywitz@web.de: 9780 → 10371
# Updated magdalena12111997@yahoo.de: 9781 → 10372
# Updated geisenhofer@gmx.net: 9782 → 10373
# Updated ursula.groeger@web.de: 9783 → 10374
# Updated smily-timmi@freenet.de: 9784 → 10375
# Updated sabinemomber@freenet.de: 9785 → 10376
# Updated patti.lauinger@web.de: 9786 → 10377
# Updated helga-ingrid.schaefer@web.de: 9787 → 10378
# Updated stefan_geisler@t-online.de: 9788 → 10379
# Updated muehlebachsandra@gmail.com: 9789 → 10380
# Updated fred.neuser@t-online.de: 9790 → 10381
# Updated ruediger-straube@freenet.de: 9791 → 10382
# Updated libelleli@yahoo.de: 9792 → 10383
# Updated cypher2003@gmx.de: 9793 → 10384
# Updated simon.frick@gmx.net: 9794 → 10385
# Updated rahelbopp@gmx.ch: 9795 → 10386
# Updated schneedoris@gmx.at: 9796 → 10387
# Updated robdehaan@outlook.com: 9797 → 10388
# Updated godolkin@gmail.com: 9798 → 10389
# Updated annemarieweydert@yahoo.com: 9799 → 10390
# Updated paulweydert@yahoo.com: 9800 → 10391
# Updated gritpropp@mail.de: 9801 → 10392
# Updated linda_kischel@web.de: 9802 → 10393
# Updated manuel.petschke@freenet.de: 9803 → 10394
# Updated fpbd@hotmail.com: 9804 → 10395
# Updated sylviaszwanda@gmail.com: 9805 → 10416
# Updated k.altvatter@gmail.com: 9806 → 10397
# Updated ramonhennemann@web.de: 9807 → 10398
# Updated genitive@web.de: 9808 → 10399
# Updated corina.nandi@googlemail.com: 9809 → 10401
# Updated domkor@gmx.de: 9810 → 10402
# Updated martin@walser.law: 9811 → 10403
# Updated yourlilliangel90@yahoo.de: 9812 → 10404
# Updated stefan.mancuso@gmx.de: 9813 → 10405
# Updated laura_nitsch@web.de: 9814 → 10406
# Updated doerthe.ramm@gmx.de: 9815 → 10407
# Updated mathiaskrause@gmail.com: 9816 → 10408
# Updated sarahkarlsruhe@aol.com: 9817 → 10409
# Updated karina.glaser@gmx.de: 9818 → 10410
# Updated stefan.ameling@posteo.de: 9819 → 10411
# Updated davidpradalgari@gmail.com: 9820 → 10477
# Updated vmsander@web.de: 9821 → 10413
# Updated eduard.benkler@gmx.de: 9822 → 10414
# Updated biancabatsch@web.de: 9823 → 10415
# Updated nrossi1@proton.me: 9824 → 10417
# Updated mima.beier@gmx.de: 9825 → 10418
# Updated carina.wessbecher@gmx.de: 9826 → 10419
# Updated jasond1984@me.com: 9827 → 10420
# Updated jessica_porth@gmx.de: 9828 → 10421
# Updated y-b-s@web.de: 9829 → 10422
# Updated tehocxx1@aol.com: 9830 → 10423
# Updated romyfei@icloud.com: 9831 → 10424
# Updated gretze@5x2.de: 9832 → 10426
# Updated m.klein-ridder@web.de: 9833 → 10427
# Updated markusjaschik@googlemail.com: 9834 → 10428
# Updated h.spruenken@googlemail.com: 9835 → 10429
# Updated braunbuchloe77@gmail.com: 9836 → 10430
# Updated atemlemtur@gmail.com: 9837 → 10431
# Updated bmadbernd@yahoo.de: 9838 → 10433
# Updated franziskajahn1988@hotmail.de: 9839 → 10434
# Updated bettina.gores@gmx.de: 9840 → 10435
# Updated wada@posteo.de: 9841 → 10436
# Updated kathrinpichlmeier@gmx.de: 9842 → 10437
# Updated alexander-appel@t-online.de: 9843 → 10438
# Updated stark-85@mail.ru: 9844 → 10439
# Updated frank.beha@t-online.de: 9845 → 10440
# Updated haraldschenker1@web.de: 9846 → 10441
# Updated raphael.ginster@gmail.com: 9847 → 10443
# Updated syba0911@t-online.de: 9848 → 10444
# Updated erwin_gebhard@web.de: 9849 → 10445
# Updated erika.laut@web.de: 9850 → 10481
# Updated alexandra_theodor@yahoo.com: 9851 → 10447
# Updated smatut@web.de: 9852 → 10448
# Updated janet_78@arcor.de: 9853 → 10449
# Updated andreas@helldoerfer.de: 9854 → 10450
# Updated f.boersch@googlemail.com: 9855 → 10451
# Updated lucasgollnick2@gmail.com: 9856 → 10452
# Updated janiarno@arcor.de: 9857 → 10453
# Updated s_bongers@yahoo.com: 9858 → 10454
# Updated sebastianfidyka@aol.com: 9859 → 10455
# Updated marc.clausen85@gmail.com: 9860 → 10456
# Updated hup.bloemer@t-online.de: 9861 → 10457
# Updated timcao24@gmail.com: 9862 → 10458
# Updated nicojunge73@gmx.de: 9863 → 10459
# Updated david.linde@posteo.de: 9864 → 10460
# Updated info@ki-2000.de: 9865 → 10461
# Updated lipp.susanna@googlemail.com: 9866 → 10462
# Updated t.voigt@fenstertechnik-brand.de: 9867 → 10463
# Updated flo-schoenwaelder@web.de: 9868 → 10464
# Updated agnes.pickl@gmx.de: 9869 → 10465
# Updated fuelfreak.gpunkt@googlemail.com: 9870 → 10466
# Updated martin.monday@gmx.de: 9871 → 10467
# Updated melanie-lauckert@web.de: 9872 → 10468
# Updated jassien.ahmed.lahsen@gmx.de: 9873 → 10469
# Updated svea-wagner@web.de: 9874 → 10470
# Updated katjatamm@web.de: 9875 → 10471
# Updated qwert@gmail.com: 9876 → 10472
# Updated johannes.kern@om.rwth-aachen.de: 9877 → 10473
# Updated firley@magenta.de: 9878 → 10474
# Updated kim.niebuhr@t-online.de: 9879 → 10475
#
# Process complete. 9874 IDs updated.
# Original JTL records: 9879
# Updated file saved to: jtl_customers_updated.csv

# %%
import pandas as pd
from datetime import datetime

def csv_to_sql_insert(csv_file_path, sql_file_path, table_name, batch_size=100):
    """
    Convert CSV data to SQL INSERT statements with strict NULL handling based on table structure.

    Args:
        csv_file_path: Path to the input CSV file
        sql_file_path: Path to save the SQL file
        table_name: Name of the target SQL table
        batch_size: Number of rows per INSERT statement
    """
    try:
        # Read CSV file
        df = pd.read_csv(csv_file_path)

        # Define column specifications based on your table structure
        column_specs = {
            'kKunde': {'null': False, 'default': None, 'type': 'int'},
            'kKundengruppe': {'null': False, 'default': '0', 'type': 'int'},
            'kSprache': {'null': False, 'default': '0', 'type': 'int'},
            'cKundenNr': {'null': True, 'default': 'NULL', 'type': 'str'},
            'cPasswort': {'null': True, 'default': 'NULL', 'type': 'str'},
            'cAnrede': {'null': False, 'default': "''", 'type': 'str'},
            'cTitel': {'null': True, 'default': 'NULL', 'type': 'str'},
            'cVorname': {'null': False, 'default': "''", 'type': 'str'},
            'cNachname': {'null': False, 'default': "''", 'type': 'str'},
            'cFirma': {'null': True, 'default': 'NULL', 'type': 'str'},
            'cZusatz': {'null': True, 'default': 'NULL', 'type': 'str'},
            'cStrasse': {'null': False, 'default': "''", 'type': 'str'},
            'cHausnummer': {'null': False, 'default': "''", 'type': 'str'},
            'cAdressZusatz': {'null': True, 'default': 'NULL', 'type': 'str'},
            'cPLZ': {'null': False, 'default': "''", 'type': 'str'},
            'cOrt': {'null': False, 'default': "''", 'type': 'str'},
            'cBundesland': {'null': False, 'default': "''", 'type': 'str'},
            'cLand': {'null': False, 'default': "''", 'type': 'str'},
            'cTel': {'null': True, 'default': 'NULL', 'type': 'str'},
            'cMobil': {'null': True, 'default': 'NULL', 'type': 'str'},
            'cFax': {'null': True, 'default': 'NULL', 'type': 'str'},
            'cMail': {'null': False, 'default': "''", 'type': 'str'},
            'cUSTID': {'null': True, 'default': 'NULL', 'type': 'str'},
            'cWWW': {'null': True, 'default': 'NULL', 'type': 'str'},
            'cSperre': {'null': False, 'default': "'N'", 'type': 'str'},
            'fGuthaben': {'null': False, 'default': '0', 'type': 'float'},
            'cNewsletter': {'null': False, 'default': "''", 'type': 'str'},
            'dGeburtstag': {'null': True, 'default': 'NULL', 'type': 'date'},
            'fRabatt': {'null': False, 'default': '0', 'type': 'float'},
            'cHerkunft': {'null': False, 'default': "''", 'type': 'str'},
            'dErstellt': {'null': True, 'default': 'NULL', 'type': 'date'},
            'dVeraendert': {'null': False, 'default': "CURRENT_TIMESTAMP", 'type': 'datetime'},
            'cAktiv': {'null': False, 'default': "'Y'", 'type': 'str'},
            'cAbgeholt': {'null': False, 'default': "'N'", 'type': 'str'},
            'nRegistriert': {'null': False, 'default': '0', 'type': 'int'},
            'nLoginversuche': {'null': False, 'default': '0', 'type': 'int'},
            'dLastLogin': {'null': True, 'default': 'NULL', 'type': 'datetime'},
            'dSessionInvalidate': {'null': True, 'default': 'NULL', 'type': 'datetime'},
            'b2FAauth': {'null': True, 'default': '0', 'type': 'int'},
            'c2FAauthSecret': {'null': True, 'default': "''", 'type': 'str'}
        }

        # Prepare SQL file
        with open(sql_file_path, 'w', encoding='utf-8') as sql_file:
            # Write SQL header
            columns = df.columns.tolist()
            sql_file.write(f"INSERT INTO `{table_name}` (\n")
            sql_file.write("    `" + "`, `".join(columns) + "`\n")
            sql_file.write(") VALUES\n")

            # Process rows in batches
            for i in range(0, len(df), batch_size):
                batch = df.iloc[i:i+batch_size]

                # Write each row in the batch
                for j, row in batch.iterrows():
                    values = []
                    for col in columns:
                        val = row[col]
                        spec = column_specs.get(col, {'null': True, 'default': 'NULL', 'type': 'str'})

                        # Handle NULL values based on column specs
                        if pd.isna(val):
                            if not spec['null']:
                                values.append(spec['default'])
                            else:
                                values.append('NULL')
                        else:
                            # Format value based on type
                            if spec['type'] == 'int':
                                values.append(str(int(val)))
                            elif spec['type'] == 'float':
                                values.append(str(float(val)))
                            elif spec['type'] == 'date':
                                if isinstance(val, str):
                                    try:
                                        dt = datetime.strptime(val, '%Y-%m-%d')
                                        values.append(f"'{dt.strftime('%Y-%m-%d')}'")
                                    except:
                                        values.append(spec['default'])
                                else:
                                    values.append(f"'{val.strftime('%Y-%m-%d')}'")
                            elif spec['type'] == 'datetime':
                                if isinstance(val, str):
                                    try:
                                        dt = datetime.strptime(val, '%Y-%m-%d %H:%M:%S')
                                        values.append(f"'{dt.strftime('%Y-%m-%d %H:%M:%S')}'")
                                    except:
                                        values.append(spec['default'])
                                else:
                                    values.append(f"'{val.strftime('%Y-%m-%d %H:%M:%S')}'")
                            else:  # string
                                val_str = str(val).replace("'", "''")
                                values.append(f"'{val_str}'")

                    # Write the VALUES line
                    sql_file.write("    (" + ", ".join(values) + ")")

                    # Add comma unless it's the last row in batch or file
                    if j != batch.index[-1] and j != df.index[-1]:
                        sql_file.write(",\n")
                    else:
                        sql_file.write(";\n\n")

                        # If more batches coming, start new INSERT statement
                        if i + batch_size < len(df):
                            sql_file.write(f"INSERT INTO `{table_name}` (\n")
                            sql_file.write("    `" + "`, `".join(columns) + "`\n")
                            sql_file.write(") VALUES\n")

        print(f"Successfully converted CSV to SQL INSERT statements. Saved to: {sql_file_path}")
        print(f"Total rows processed: {len(df)}")

    except Exception as e:
        print(f"Error: {str(e)}")

# Configuration
if __name__ == "__main__":
    CSV_FILE = "jtl_customers_updated.csv"  # Your input CSV file
    SQL_FILE = "jtl_customers_inserts.sql"  # Output SQL file
    TABLE_NAME = "tkunde"  # Your target table name
    BATCH_SIZE = 100  # Rows per INSERT statement

    print("Starting CSV to SQL conversion with strict NULL handling...")
    csv_to_sql_insert(CSV_FILE, SQL_FILE, TABLE_NAME, BATCH_SIZE)
# Out:
# Starting CSV to SQL conversion with strict NULL handling...
# Successfully converted CSV to SQL INSERT statements. Saved to: jtl_customers_inserts.sql
# Total rows processed: 9879

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import chardet
import logging

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    filename='shopware_to_jtl.log',
    filemode='w'
)
logger = logging.getLogger()

def detect_encoding(file_path):
    """Detect file encoding using chardet"""
    try:
        with open(file_path, 'rb') as f:
            result = chardet.detect(f.read())
        return result['encoding']
    except Exception as e:
        logger.error(f"Error detecting encoding for {file_path}: {str(e)}")
        return 'utf-8'  # Fallback to utf-8

def convert_shopware_to_jtl_orders(shopware_csv, jtl_customers_csv, output_prefix):
    """
    Complete conversion of Shopware 5 orders to JTL Shop 5 format.
    Matches customers by customerId (Shopware) to kKunde (JTL).
    """
    try:
        logger.info("Starting conversion process...")

        # Detect and load files with proper encoding
        shopware_encoding = detect_encoding(shopware_csv)
        jtl_encoding = detect_encoding(jtl_customers_csv)

        logger.info(f"Loading {shopware_csv} with {shopware_encoding} encoding")
        shopware_orders = pd.read_csv(shopware_csv, decimal=',', encoding=shopware_encoding)

        logger.info(f"Loading {jtl_customers_csv} with {jtl_encoding} encoding")
        jtl_customers = pd.read_csv(jtl_customers_csv, encoding=jtl_encoding)

        # Create mapping from customerId to kKunde (they should be the same)
        customer_id_to_kKunde = dict(zip(
            jtl_customers['kKunde'],
            jtl_customers['kKunde']
        ))

        # Initialize DataFrames for JTL tables
        columns = {
            'tlieferadresse': [
                'kLieferadresse', 'kKunde', 'cAnrede', 'cVorname', 'cNachname',
                'cTitel', 'cFirma', 'cZusatz', 'cStrasse', 'cHausnummer',
                'cAdressZusatz', 'cPLZ', 'cOrt', 'cBundesland', 'cLand',
                'cTel', 'cMobil', 'cFax', 'cMail'
            ],
            'twarenkorb': [
                'kWarenkorb', 'kKunde', 'kLieferadresse', 'kZahlungsInfo'
            ],
            'twarenkorbpos': [
                'kWarenkorbPos', 'kWarenkorb', 'kArtikel', 'kVersandklasse',
                'cName', 'cLieferstatus', 'cArtNr', 'cEinheit', 'fPreisEinzelNetto',
                'fPreis', 'fMwSt', 'nAnzahl', 'nPosTyp', 'cHinweis', 'cUnique',
                'cResponsibility', 'kKonfigitem', 'kBestellpos', 'fLagerbestandVorAbschluss',
                'nLongestMinDelivery', 'nLongestMaxDelivery'
            ],
            'twarenkorbpers': [
                'kKunde', 'dErstellt'
            ]
        }

        tables = {
            'tlieferadresse': pd.DataFrame(columns=columns['tlieferadresse']),
            'twarenkorb': pd.DataFrame(columns=columns['twarenkorb']),
            'twarenkorbpos': pd.DataFrame(columns=columns['twarenkorbpos']),
            'twarenkorbpers': pd.DataFrame(columns=columns['twarenkorbpers'])
        }

        # Initialize IDs
        current_ids = {
            'lieferadresse': 3,
            'warenkorb': 5,
            'warenkorbpos': 26
        }

        # Statistics
        stats = {
            'total_orders': 0,
            'matched_orders': 0,
            'skipped_orders': 0,
            'total_items': 0
        }

        logger.info("Processing orders...")

        # Process each unique order (group by orderId)
        for order_id, order_group in shopware_orders.groupby('orderId'):
            stats['total_orders'] += 1
            first_row = order_group.iloc[0]
            customer_id = first_row['customerId']

            # Match customer by customerId (Shopware) to kKunde (JTL)
            kKunde = customer_id_to_kKunde.get(customer_id)

            if kKunde is None:
                logger.warning(f"No JTL customer found for order {order_id} with customerId {customer_id}")
                stats['skipped_orders'] += 1
                continue

            stats['matched_orders'] += 1

            # Parse order time (handle multiple date formats)
            order_time = None
            for fmt in ('%d/%m/%Y %H:%M', '%m/%d/%Y %H:%M', '%Y-%m-%d %H:%M:%S'):
                try:
                    order_time = datetime.strptime(first_row['orderTime'], fmt)
                    break
                except ValueError:
                    continue

            if order_time is None:
                logger.warning(f"Could not parse date for order {order_id}: {first_row['orderTime']}")
                order_time = datetime.now()

            # 1. tlieferadresse (shipping address)
            tables['tlieferadresse'].loc[len(tables['tlieferadresse'])] = {
                'kLieferadresse': current_ids['lieferadresse'],
                'kKunde': kKunde,
                'cAnrede': first_row.get('salutation', 'm'),
                'cVorname': first_row.get('firstname', ''),
                'cNachname': first_row.get('lastname', ''),
                'cTitel': first_row.get('title', ''),
                'cFirma': first_row.get('company', ''),
                'cZusatz': first_row.get('additional_address_line1', ''),
                'cStrasse': first_row.get('street', ''),
                'cHausnummer': first_row.get('streetnumber', '8'),
                'cAdressZusatz': first_row.get('additional_address_line2', ''),
                'cPLZ': first_row.get('zipcode', '48527'),
                'cOrt': first_row.get('city', 'Nordhorn'),
                'cBundesland': first_row.get('state', ''),
                'cLand': first_row.get('country', 'DE'),
                'cTel': first_row.get('phone', ''),
                'cMobil': first_row.get('mobile', ''),
                'cFax': first_row.get('fax', ''),
                'cMail': first_row.get('email', '')
            }

            # 2. twarenkorb (order header)
            tables['twarenkorb'].loc[len(tables['twarenkorb'])] = {
                'kWarenkorb': current_ids['warenkorb'],
                'kKunde': kKunde,
                'kLieferadresse': current_ids['lieferadresse'],
                'kZahlungsInfo': first_row['paymentID']  # Use Shopware payment ID directly
            }

            # 3. twarenkorbpos (order items)
            for _, item in order_group.iterrows():
                stats['total_items'] += 1

                # Convert price from string to float (handling EU decimal format)
                try:
                    price = float(str(item['price']).replace(',', '.'))
                except:
                    price = 0.0
                    logger.warning(f"Could not parse price for item {item['articleNumber']} in order {order_id}")

                # Main product (PosTyp 1)
                tables['twarenkorbpos'].loc[len(tables['twarenkorbpos'])] = {
                    'kWarenkorbPos': current_ids['warenkorbpos'],
                    'kWarenkorb': current_ids['warenkorb'],
                    'kArtikel': 0,  # Needs mapping to JTL articles
                    'kVersandklasse': 6 if current_ids['warenkorbpos'] % 2 == 0 else 1,
                    'cName': str(item['articleName']),
                    'cLieferstatus': 'completed',
                    'cArtNr': str(item['articleNumber']),
                    'cEinheit': 'Stück',
                    'fPreisEinzelNetto': price,
                    'fPreis': price * int(item['quantity']),
                    'fMwSt': float(item['taxRate']),
                    'nAnzahl': int(item['quantity']),
                    'nPosTyp': 1,  # 1=article
                    'cHinweis': '',
                    'cUnique': 'core',
                    'cResponsibility': '',
                    'kKonfigitem': 0,
                    'kBestellpos': 87000 + current_ids['warenkorbpos'],
                    'fLagerbestandVorAbschluss': np.nan,
                    'nLongestMinDelivery': 2,
                    'nLongestMaxDelivery': 3
                }
                current_ids['warenkorbpos'] += 1

            # Add shipping cost (PosTyp 2)
            try:
                shipping_net = float(str(first_row['invoiceShippingNet']).replace(',', '.'))
                shipping = float(str(first_row['invoiceShipping']).replace(',', '.'))
            except:
                shipping_net = 4.19
                shipping = 4.99
                logger.warning(f"Could not parse shipping costs for order {order_id}")

            tables['twarenkorbpos'].loc[len(tables['twarenkorbpos'])] = {
                'kWarenkorbPos': current_ids['warenkorbpos'],
                'kWarenkorb': current_ids['warenkorb'],
                'kArtikel': 0,
                'kVersandklasse': 0,
                'cName': 'DHL',  # Default shipping method
                'cLieferstatus': 'completed',
                'cArtNr': '',
                'cEinheit': 'Stück',
                'fPreisEinzelNetto': shipping_net,
                'fPreis': shipping,
                'fMwSt': shipping - shipping_net,
                'nAnzahl': 1,
                'nPosTyp': 2,  # 2=shipping
                'cHinweis': '',
                'cUnique': 'core',
                'cResponsibility': '',
                'kKonfigitem': 0,
                'kBestellpos': 87000 + current_ids['warenkorbpos'],
                'fLagerbestandVorAbschluss': np.nan,
                'nLongestMinDelivery': 0,
                'nLongestMaxDelivery': 0
            }
            current_ids['warenkorbpos'] += 1

            # 4. twarenkorbpers (order person)
            tables['twarenkorbpers'].loc[len(tables['twarenkorbpers'])] = {
                'kKunde': kKunde,
                'dErstellt': order_time.strftime('%Y-%m-%d %H:%M:%S')
            }

            # Increment IDs for next order
            current_ids['lieferadresse'] += 1
            current_ids['warenkorb'] += 1

        logger.info("Saving output files...")
        # Save all tables to CSV with UTF-8 encoding
        for table_name, df in tables.items():
            output_file = f"{output_prefix}_{table_name}.csv"
            df.to_csv(output_file, index=False, encoding='utf-8')
            logger.info(f"Saved {output_file} with {len(df)} records")

        # Print summary statistics
        logger.info("\nConversion Summary:")
        logger.info(f"Total Orders Processed: {stats['total_orders']}")
        logger.info(f"Successfully Matched Orders: {stats['matched_orders']}")
        logger.info(f"Skipped Orders (no customer match): {stats['skipped_orders']}")
        logger.info(f"Total Order Items Processed: {stats['total_items']}")
        logger.info(f"Generated files with prefix: {output_prefix}_*.csv")

        print("\nConversion completed successfully! Check shopware_to_jtl.log for details.")

    except Exception as e:
        logger.error(f"Fatal error during conversion: {str(e)}", exc_info=True)
        print(f"\nError: {str(e)}\nCheck shopware_to_jtl.log for details.")

if __name__ == "__main__":
    # Configuration - update these paths
    SHOPWARE_CSV = "shopware_order_07.csv"       # Path to Shopware orders CSV
    JTL_CUSTOMERS_CSV = "jtl_customers.csv"    # Path to JTL customers CSV
    OUTPUT_PREFIX = "jtl_orders"               # Prefix for output files

    print("=== Shopware 5 to JTL Shop 5 Order Conversion ===")
    print("This script will convert Shopware orders to JTL format.")
    print(f"Input files: {SHOPWARE_CSV}, {JTL_CUSTOMERS_CSV}")
    print(f"Output prefix: {OUTPUT_PREFIX}_*.csv")
    print("Detailed logs will be written to shopware_to_jtl.log\n")

    convert_shopware_to_jtl_orders(SHOPWARE_CSV, JTL_CUSTOMERS_CSV, OUTPUT_PREFIX)
# Out:
# === Shopware 5 to JTL Shop 5 Order Conversion ===
# This script will convert Shopware orders to JTL format.
# Input files: shopware_order_07.csv, jtl_customers.csv
# Output prefix: jtl_orders_*.csv
# Detailed logs will be written to shopware_to_jtl.log
# WARNING:root:No JTL customer found for order 5 with customerId 6
# WARNING:root:No JTL customer found for order 110 with customerId 58
# WARNING:root:No JTL customer found for order 158 with customerId 84
# WARNING:root:No JTL customer found for order 160 with customerId 85
# WARNING:root:No JTL customer found for order 243 with customerId 123
# WARNING:root:No JTL customer found for order 267 with customerId 133
# WARNING:root:No JTL customer found for order 319 with customerId 155
# WARNING:root:No JTL customer found for order 370 with customerId 172
# WARNING:root:No JTL customer found for order 471 with customerId 215
# WARNING:root:No JTL customer found for order 497 with customerId 228
# WARNING:root:No JTL customer found for order 510 with customerId 236
# WARNING:root:No JTL customer found for order 561 with customerId 256
# WARNING:root:No JTL customer found for order 562 with customerId 256
# WARNING:root:No JTL customer found for order 591 with customerId 266
# WARNING:root:No JTL customer found for order 610 with customerId 273
# WARNING:root:No JTL customer found for order 629 with customerId 280
# WARNING:root:No JTL customer found for order 685 with customerId 300
# WARNING:root:No JTL customer found for order 751 with customerId 328
# WARNING:root:No JTL customer found for order 817 with customerId 351
# WARNING:root:No JTL customer found for order 838 with customerId 362
# WARNING:root:No JTL customer found for order 874 with customerId 374
# WARNING:root:No JTL customer found for order 927 with customerId 401
# WARNING:root:No JTL customer found for order 956 with customerId 413
# WARNING:root:No JTL customer found for order 981 with customerId 424
# WARNING:root:No JTL customer found for order 1012 with customerId 440
# WARNING:root:No JTL customer found for order 1014 with customerId 441
# WARNING:root:No JTL customer found for order 1016 with customerId 442
# WARNING:root:No JTL customer found for order 1086 with customerId 468
# WARNING:root:No JTL customer found for order 1105 with customerId 479
# WARNING:root:No JTL customer found for order 1182 with customerId 506
# WARNING:root:No JTL customer found for order 1210 with customerId 518
# WARNING:root:No JTL customer found for order 1216 with customerId 522
# WARNING:root:No JTL customer found for order 1218 with customerId 523
# WARNING:root:No JTL customer found for order 1228 with customerId 529
# WARNING:root:No JTL customer found for order 1341 with customerId 580
# WARNING:root:No JTL customer found for order 1408 with customerId 609
# WARNING:root:No JTL customer found for order 1421 with customerId 615
# WARNING:root:No JTL customer found for order 1430 with customerId 617
# WARNING:root:No JTL customer found for order 1503 with customerId 617
# WARNING:root:No JTL customer found for order 1550 with customerId 669
# WARNING:root:No JTL customer found for order 1629 with customerId 706
# WARNING:root:No JTL customer found for order 1634 with customerId 709
# WARNING:root:No JTL customer found for order 1660 with customerId 719
# WARNING:root:No JTL customer found for order 1664 with customerId 722
# WARNING:root:No JTL customer found for order 1665 with customerId 723
# WARNING:root:No JTL customer found for order 1666 with customerId 724
# WARNING:root:No JTL customer found for order 1671 with customerId 733
# WARNING:root:No JTL customer found for order 1694 with customerId 743
# WARNING:root:No JTL customer found for order 1734 with customerId 753
# WARNING:root:No JTL customer found for order 1737 with customerId 754
# WARNING:root:No JTL customer found for order 1753 with customerId 760
# WARNING:root:No JTL customer found for order 1854 with customerId 805
# WARNING:root:No JTL customer found for order 1959 with customerId 856
# WARNING:root:No JTL customer found for order 1973 with customerId 863
# WARNING:root:No JTL customer found for order 2068 with customerId 904
# WARNING:root:No JTL customer found for order 2131 with customerId 931
# WARNING:root:No JTL customer found for order 2135 with customerId 934
# WARNING:root:No JTL customer found for order 2248 with customerId 983
# WARNING:root:No JTL customer found for order 2254 with customerId 986
# WARNING:root:No JTL customer found for order 2295 with customerId 1005
# WARNING:root:No JTL customer found for order 2372 with customerId 1039
# WARNING:root:No JTL customer found for order 2399 with customerId 1052
# WARNING:root:No JTL customer found for order 2403 with customerId 1054
# WARNING:root:No JTL customer found for order 2538 with customerId 1108
# WARNING:root:No JTL customer found for order 2765 with customerId 1189
# WARNING:root:No JTL customer found for order 2826 with customerId 1212
# WARNING:root:No JTL customer found for order 2828 with customerId 1214
# WARNING:root:No JTL customer found for order 2852 with customerId 1227
# WARNING:root:No JTL customer found for order 2854 with customerId 1227
# WARNING:root:No JTL customer found for order 2881 with customerId 1236
# WARNING:root:No JTL customer found for order 3043 with customerId 1301
# WARNING:root:No JTL customer found for order 3053 with customerId 1307
# WARNING:root:No JTL customer found for order 3128 with customerId 1340
# WARNING:root:No JTL customer found for order 3170 with customerId 1359
# WARNING:root:No JTL customer found for order 3187 with customerId 1367
# WARNING:root:No JTL customer found for order 3225 with customerId 1386
# WARNING:root:No JTL customer found for order 3388 with customerId 1448
# WARNING:root:No JTL customer found for order 3410 with customerId 1459
# WARNING:root:No JTL customer found for order 3412 with customerId 1460
# WARNING:root:No JTL customer found for order 3482 with customerId 1489
# WARNING:root:No JTL customer found for order 3498 with customerId 1495
# WARNING:root:No JTL customer found for order 3500 with customerId 1496
# WARNING:root:No JTL customer found for order 3529 with customerId 1507
# WARNING:root:No JTL customer found for order 3623 with customerId 1542
# WARNING:root:No JTL customer found for order 3688 with customerId 1568
# WARNING:root:No JTL customer found for order 3722 with customerId 1585
# WARNING:root:No JTL customer found for order 3859 with customerId 1643
# WARNING:root:No JTL customer found for order 3878 with customerId 1654
# WARNING:root:No JTL customer found for order 3958 with customerId 1684
# WARNING:root:No JTL customer found for order 4031 with customerId 1711
# WARNING:root:No JTL customer found for order 4054 with customerId 1719
# WARNING:root:No JTL customer found for order 4055 with customerId 1720
# WARNING:root:No JTL customer found for order 4066 with customerId 1726
# WARNING:root:No JTL customer found for order 4083 with customerId 1734
# WARNING:root:No JTL customer found for order 4124 with customerId 754
# WARNING:root:No JTL customer found for order 4200 with customerId 1568
# WARNING:root:No JTL customer found for order 4213 with customerId 1784
# WARNING:root:No JTL customer found for order 4274 with customerId 1809
# WARNING:root:No JTL customer found for order 4411 with customerId 1858
# WARNING:root:No JTL customer found for order 4424 with customerId 1861
# WARNING:root:No JTL customer found for order 4502 with customerId 1889
# WARNING:root:No JTL customer found for order 4548 with customerId 1906
# WARNING:root:No JTL customer found for order 4592 with customerId 1448
# WARNING:root:No JTL customer found for order 4663 with customerId 1961
# WARNING:root:No JTL customer found for order 4664 with customerId 1962
# WARNING:root:No JTL customer found for order 4681 with customerId 1972
# WARNING:root:No JTL customer found for order 4716 with customerId 1991
# WARNING:root:No JTL customer found for order 4724 with customerId 1994
# WARNING:root:No JTL customer found for order 4726 with customerId 1995
# WARNING:root:No JTL customer found for order 4836 with customerId 2044
# WARNING:root:No JTL customer found for order 4892 with customerId 2072
# WARNING:root:No JTL customer found for order 4958 with customerId 2097
# WARNING:root:No JTL customer found for order 5015 with customerId 2121
# WARNING:root:No JTL customer found for order 5132 with customerId 2165
# WARNING:root:No JTL customer found for order 5172 with customerId 2184
# WARNING:root:No JTL customer found for order 5217 with customerId 1568
# WARNING:root:No JTL customer found for order 5219 with customerId 1568
# WARNING:root:No JTL customer found for order 5241 with customerId 2217
# WARNING:root:No JTL customer found for order 5283 with customerId 2235
# WARNING:root:No JTL customer found for order 5385 with customerId 2276
# WARNING:root:No JTL customer found for order 5427 with customerId 2293
# WARNING:root:No JTL customer found for order 5446 with customerId 2300
# WARNING:root:No JTL customer found for order 5577 with customerId 2355
# WARNING:root:No JTL customer found for order 5580 with customerId 2358
# WARNING:root:No JTL customer found for order 5581 with customerId 2359
# WARNING:root:No JTL customer found for order 5624 with customerId 2379
# WARNING:root:No JTL customer found for order 5648 with customerId 2388
# WARNING:root:No JTL customer found for order 5696 with customerId 2406
# WARNING:root:No JTL customer found for order 5700 with customerId 2408
# WARNING:root:No JTL customer found for order 5787 with customerId 2442
# WARNING:root:No JTL customer found for order 5857 with customerId 2475
# WARNING:root:No JTL customer found for order 5925 with customerId 2500
# WARNING:root:No JTL customer found for order 5927 with customerId 2501
# WARNING:root:No JTL customer found for order 5995 with customerId 2520
# WARNING:root:No JTL customer found for order 6040 with customerId 2541
# WARNING:root:No JTL customer found for order 6090 with customerId 2562
# WARNING:root:No JTL customer found for order 6146 with customerId 2589
# WARNING:root:No JTL customer found for order 6170 with customerId 2599
# WARNING:root:No JTL customer found for order 6194 with customerId 2614
# WARNING:root:No JTL customer found for order 6206 with customerId 2617
# WARNING:root:No JTL customer found for order 6238 with customerId 2632
# WARNING:root:No JTL customer found for order 6270 with customerId 2645
# WARNING:root:No JTL customer found for order 6338 with customerId 2672
# WARNING:root:No JTL customer found for order 6343 with customerId 2675
# WARNING:root:No JTL customer found for order 6367 with customerId 2683
# WARNING:root:No JTL customer found for order 6389 with customerId 2696
# WARNING:root:No JTL customer found for order 6575 with customerId 2770
# WARNING:root:No JTL customer found for order 6660 with customerId 2807
# WARNING:root:No JTL customer found for order 6725 with customerId 2836
# WARNING:root:No JTL customer found for order 6755 with customerId 2852
# WARNING:root:No JTL customer found for order 6801 with customerId 2874
# WARNING:root:No JTL customer found for order 6819 with customerId 2880
# WARNING:root:No JTL customer found for order 6935 with customerId 2925
# WARNING:root:No JTL customer found for order 6970 with customerId 2939
# WARNING:root:No JTL customer found for order 7070 with customerId 2976
# WARNING:root:No JTL customer found for order 7120 with customerId 2994
# WARNING:root:No JTL customer found for order 7125 with customerId 2995
# WARNING:root:No JTL customer found for order 7168 with customerId 3012
# WARNING:root:No JTL customer found for order 7228 with customerId 3034
# WARNING:root:No JTL customer found for order 7250 with customerId 2994
# WARNING:root:No JTL customer found for order 7303 with customerId 3072
# WARNING:root:No JTL customer found for order 7320 with customerId 3079
# WARNING:root:No JTL customer found for order 7336 with customerId 3087
# WARNING:root:No JTL customer found for order 7354 with customerId 3097
# WARNING:root:No JTL customer found for order 7385 with customerId 3110
# WARNING:root:No JTL customer found for order 7411 with customerId 3123
# WARNING:root:No JTL customer found for order 7426 with customerId 3129
# WARNING:root:No JTL customer found for order 7469 with customerId 3146
# WARNING:root:No JTL customer found for order 7529 with customerId 3172
# WARNING:root:No JTL customer found for order 7580 with customerId 3190
# WARNING:root:No JTL customer found for order 7599 with customerId 3198
# WARNING:root:No JTL customer found for order 7608 with customerId 3202
# WARNING:root:No JTL customer found for order 7609 with customerId 3203
# WARNING:root:No JTL customer found for order 7624 with customerId 3211
# WARNING:root:No JTL customer found for order 7643 with customerId 3219
# WARNING:root:No JTL customer found for order 7651 with customerId 3221
# WARNING:root:No JTL customer found for order 7728 with customerId 3256
# WARNING:root:No JTL customer found for order 7747 with customerId 3266
# WARNING:root:No JTL customer found for order 7764 with customerId 3273
# WARNING:root:No JTL customer found for order 7836 with customerId 3302
# WARNING:root:No JTL customer found for order 7838 with customerId 3303
# WARNING:root:No JTL customer found for order 7843 with customerId 3305
# WARNING:root:No JTL customer found for order 7848 with customerId 3306
# WARNING:root:No JTL customer found for order 7857 with customerId 3309
# WARNING:root:No JTL customer found for order 7863 with customerId 3312
# WARNING:root:No JTL customer found for order 7867 with customerId 3314
# WARNING:root:No JTL customer found for order 7948 with customerId 3354
# WARNING:root:No JTL customer found for order 7959 with customerId 3358
# WARNING:root:No JTL customer found for order 8009 with customerId 3379
# WARNING:root:No JTL customer found for order 8037 with customerId 1448
# WARNING:root:No JTL customer found for order 8096 with customerId 3417
# WARNING:root:No JTL customer found for order 8129 with customerId 3434
# WARNING:root:No JTL customer found for order 8138 with customerId 3440
# WARNING:root:No JTL customer found for order 8179 with customerId 3457
# WARNING:root:No JTL customer found for order 8196 with customerId 3467
# WARNING:root:No JTL customer found for order 8323 with customerId 3523
# WARNING:root:No JTL customer found for order 8327 with customerId 3525
# WARNING:root:No JTL customer found for order 8328 with customerId 3526
# WARNING:root:No JTL customer found for order 8363 with customerId 3540
# WARNING:root:No JTL customer found for order 8365 with customerId 3541
# WARNING:root:No JTL customer found for order 8375 with customerId 3541
# WARNING:root:No JTL customer found for order 8376 with customerId 3545
# WARNING:root:No JTL customer found for order 8431 with customerId 3567
# WARNING:root:No JTL customer found for order 8433 with customerId 3568
# WARNING:root:No JTL customer found for order 8435 with customerId 3569
# WARNING:root:No JTL customer found for order 8446 with customerId 3574
# WARNING:root:No JTL customer found for order 8449 with customerId 3541
# WARNING:root:No JTL customer found for order 8512 with customerId 3604
# WARNING:root:No JTL customer found for order 8525 with customerId 3614
# WARNING:root:No JTL customer found for order 8545 with customerId 3623
# WARNING:root:No JTL customer found for order 8564 with customerId 3628
# WARNING:root:No JTL customer found for order 8597 with customerId 3541
# WARNING:root:No JTL customer found for order 8600 with customerId 3639
# WARNING:root:No JTL customer found for order 8653 with customerId 3663
# WARNING:root:No JTL customer found for order 8685 with customerId 3671
# WARNING:root:No JTL customer found for order 8709 with customerId 3683
# WARNING:root:No JTL customer found for order 8712 with customerId 3684
# WARNING:root:No JTL customer found for order 8807 with customerId 3717
# WARNING:root:No JTL customer found for order 8838 with customerId 3729
# WARNING:root:No JTL customer found for order 8840 with customerId 3730
# WARNING:root:No JTL customer found for order 8937 with customerId 3771
# WARNING:root:No JTL customer found for order 8940 with customerId 3773
# WARNING:root:No JTL customer found for order 8942 with customerId 3774
# WARNING:root:No JTL customer found for order 8960 with customerId 3782
# WARNING:root:No JTL customer found for order 8972 with customerId 3786
# WARNING:root:No JTL customer found for order 8975 with customerId 3774
# WARNING:root:No JTL customer found for order 9002 with customerId 3802
# WARNING:root:No JTL customer found for order 9031 with customerId 3814
# WARNING:root:No JTL customer found for order 9033 with customerId 3815
# WARNING:root:No JTL customer found for order 9124 with customerId 3849
# WARNING:root:No JTL customer found for order 9198 with customerId 3884
# WARNING:root:No JTL customer found for order 9204 with customerId 3887
# WARNING:root:No JTL customer found for order 9233 with customerId 3900
# WARNING:root:No JTL customer found for order 9235 with customerId 3901
# WARNING:root:No JTL customer found for order 9318 with customerId 3814
# WARNING:root:No JTL customer found for order 9339 with customerId 3947
# WARNING:root:No JTL customer found for order 9381 with customerId 3969
# WARNING:root:No JTL customer found for order 9421 with customerId 3987
# WARNING:root:No JTL customer found for order 9631 with customerId 4071
# WARNING:root:No JTL customer found for order 9656 with customerId 4085
# WARNING:root:No JTL customer found for order 9663 with customerId 4088
# WARNING:root:No JTL customer found for order 9701 with customerId 4101
# WARNING:root:No JTL customer found for order 9714 with customerId 4107
# WARNING:root:No JTL customer found for order 9755 with customerId 4128
# WARNING:root:No JTL customer found for order 9877 with customerId 4175
# WARNING:root:No JTL customer found for order 9950 with customerId 4207
# WARNING:root:No JTL customer found for order 9987 with customerId 4219
# WARNING:root:No JTL customer found for order 10025 with customerId 4239
# WARNING:root:No JTL customer found for order 10084 with customerId 4258
# WARNING:root:No JTL customer found for order 10170 with customerId 4289
# WARNING:root:No JTL customer found for order 10180 with customerId 4294
# WARNING:root:No JTL customer found for order 10202 with customerId 4304
# WARNING:root:No JTL customer found for order 10205 with customerId 4306
# WARNING:root:No JTL customer found for order 10254 with customerId 4322
# WARNING:root:No JTL customer found for order 10326 with customerId 4354
# WARNING:root:No JTL customer found for order 10363 with customerId 4219
# WARNING:root:No JTL customer found for order 10449 with customerId 4407
# WARNING:root:No JTL customer found for order 10523 with customerId 4444
# WARNING:root:No JTL customer found for order 10550 with customerId 4456
# WARNING:root:No JTL customer found for order 10567 with customerId 4464
# WARNING:root:No JTL customer found for order 10569 with customerId 4467
# WARNING:root:No JTL customer found for order 10616 with customerId 4491
# WARNING:root:No JTL customer found for order 10625 with customerId 4495
# WARNING:root:No JTL customer found for order 10629 with customerId 4497
# WARNING:root:No JTL customer found for order 10641 with customerId 4503
# WARNING:root:No JTL customer found for order 10653 with customerId 4509
# WARNING:root:No JTL customer found for order 10678 with customerId 4520
# WARNING:root:No JTL customer found for order 10709 with customerId 4537
# WARNING:root:No JTL customer found for order 10715 with customerId 4539
# WARNING:root:No JTL customer found for order 10809 with customerId 4586
# WARNING:root:No JTL customer found for order 10817 with customerId 4591
# WARNING:root:No JTL customer found for order 10824 with customerId 4594
# WARNING:root:No JTL customer found for order 10900 with customerId 4628
# WARNING:root:No JTL customer found for order 10914 with customerId 4631
# WARNING:root:No JTL customer found for order 10974 with customerId 4657
# WARNING:root:No JTL customer found for order 11002 with customerId 4666
# WARNING:root:No JTL customer found for order 11037 with customerId 4680
# WARNING:root:No JTL customer found for order 11105 with customerId 4707
# WARNING:root:No JTL customer found for order 11115 with customerId 4712
# WARNING:root:No JTL customer found for order 11167 with customerId 4737
# WARNING:root:No JTL customer found for order 11212 with customerId 4755
# WARNING:root:No JTL customer found for order 11221 with customerId 4759
# WARNING:root:No JTL customer found for order 11227 with customerId 4763
# WARNING:root:No JTL customer found for order 11292 with customerId 4790
# WARNING:root:No JTL customer found for order 11346 with customerId 4818
# WARNING:root:No JTL customer found for order 11376 with customerId 4831
# WARNING:root:No JTL customer found for order 11387 with customerId 4838
# WARNING:root:No JTL customer found for order 11423 with customerId 617
# WARNING:root:No JTL customer found for order 11479 with customerId 4875
# WARNING:root:No JTL customer found for order 11614 with customerId 4933
# WARNING:root:No JTL customer found for order 11689 with customerId 4969
# WARNING:root:No JTL customer found for order 11696 with customerId 4973
# WARNING:root:No JTL customer found for order 11749 with customerId 4994
# WARNING:root:No JTL customer found for order 11805 with customerId 5018
# WARNING:root:No JTL customer found for order 11821 with customerId 5026
# WARNING:root:No JTL customer found for order 11850 with customerId 5037
# WARNING:root:No JTL customer found for order 11876 with customerId 5050
# WARNING:root:No JTL customer found for order 11987 with customerId 5095
# WARNING:root:No JTL customer found for order 12092 with customerId 5134
# WARNING:root:No JTL customer found for order 12095 with customerId 5135
# WARNING:root:No JTL customer found for order 12209 with customerId 5181
# WARNING:root:No JTL customer found for order 12272 with customerId 5205
# WARNING:root:No JTL customer found for order 12281 with customerId 5209
# WARNING:root:No JTL customer found for order 12333 with customerId 5236
# WARNING:root:No JTL customer found for order 12368 with customerId 5252
# WARNING:root:No JTL customer found for order 12559 with customerId 5329
# WARNING:root:No JTL customer found for order 12620 with customerId 5359
# WARNING:root:No JTL customer found for order 12635 with customerId 5365
# WARNING:root:No JTL customer found for order 12700 with customerId 5390
# WARNING:root:No JTL customer found for order 12739 with customerId 5390
# WARNING:root:No JTL customer found for order 12752 with customerId 5411
# WARNING:root:No JTL customer found for order 12769 with customerId 5420
# WARNING:root:No JTL customer found for order 12789 with customerId 5431
# WARNING:root:No JTL customer found for order 12792 with customerId 5432
# WARNING:root:No JTL customer found for order 12827 with customerId 5445
# WARNING:root:No JTL customer found for order 12829 with customerId 5446
# WARNING:root:No JTL customer found for order 12846 with customerId 5454
# WARNING:root:No JTL customer found for order 12849 with customerId 5457
# WARNING:root:No JTL customer found for order 12853 with customerId 5455
# WARNING:root:No JTL customer found for order 12890 with customerId 5474
# WARNING:root:No JTL customer found for order 12934 with customerId 5493
# WARNING:root:No JTL customer found for order 12963 with customerId 5504
# WARNING:root:No JTL customer found for order 12966 with customerId 5505
# WARNING:root:No JTL customer found for order 12972 with customerId 5508
# WARNING:root:No JTL customer found for order 13030 with customerId 5532
# WARNING:root:No JTL customer found for order 13112 with customerId 5577
# WARNING:root:No JTL customer found for order 13124 with customerId 5581
# WARNING:root:No JTL customer found for order 13136 with customerId 3814
# WARNING:root:No JTL customer found for order 13138 with customerId 3814
# WARNING:root:No JTL customer found for order 13160 with customerId 5594
# WARNING:root:No JTL customer found for order 13285 with customerId 5646
# WARNING:root:No JTL customer found for order 13287 with customerId 5648
# WARNING:root:No JTL customer found for order 13360 with customerId 5682
# WARNING:root:No JTL customer found for order 13364 with customerId 5684
# WARNING:root:No JTL customer found for order 13382 with customerId 5691
# WARNING:root:No JTL customer found for order 13389 with customerId 5693
# WARNING:root:No JTL customer found for order 13398 with customerId 5696
# WARNING:root:No JTL customer found for order 13413 with customerId 5704
# WARNING:root:No JTL customer found for order 13437 with customerId 5716
# WARNING:root:No JTL customer found for order 13534 with customerId 5759
# WARNING:root:No JTL customer found for order 13565 with customerId 5776
# WARNING:root:No JTL customer found for order 13674 with customerId 617
# WARNING:root:No JTL customer found for order 13697 with customerId 5834
# WARNING:root:No JTL customer found for order 13700 with customerId 5836
# WARNING:root:No JTL customer found for order 13757 with customerId 3541
# WARNING:root:No JTL customer found for order 13782 with customerId 5875
# WARNING:root:No JTL customer found for order 13889 with customerId 5927
# WARNING:root:No JTL customer found for order 13949 with customerId 5950
# WARNING:root:No JTL customer found for order 13962 with customerId 5954
# WARNING:root:No JTL customer found for order 13965 with customerId 5955
# WARNING:root:No JTL customer found for order 14014 with customerId 5978
# WARNING:root:No JTL customer found for order 14052 with customerId 5991
# WARNING:root:No JTL customer found for order 14071 with customerId 5997
# WARNING:root:No JTL customer found for order 14076 with customerId 5950
# WARNING:root:No JTL customer found for order 14091 with customerId 6005
# WARNING:root:No JTL customer found for order 14175 with customerId 6041
# WARNING:root:No JTL customer found for order 14177 with customerId 6042
# WARNING:root:No JTL customer found for order 14192 with customerId 6048
# WARNING:root:No JTL customer found for order 14229 with customerId 6069
# WARNING:root:No JTL customer found for order 14284 with customerId 6095
# WARNING:root:No JTL customer found for order 14312 with customerId 6106
# WARNING:root:No JTL customer found for order 14336 with customerId 6115
# WARNING:root:No JTL customer found for order 14366 with customerId 6129
# WARNING:root:No JTL customer found for order 14386 with customerId 6137
# WARNING:root:No JTL customer found for order 14388 with customerId 6137
# WARNING:root:No JTL customer found for order 14390 with customerId 6137
# WARNING:root:No JTL customer found for order 14442 with customerId 6161
# WARNING:root:No JTL customer found for order 14544 with customerId 6205
# WARNING:root:No JTL customer found for order 14559 with customerId 6211
# WARNING:root:No JTL customer found for order 14608 with customerId 6234
# WARNING:root:No JTL customer found for order 14625 with customerId 6241
# WARNING:root:No JTL customer found for order 14640 with customerId 6249
# WARNING:root:No JTL customer found for order 14649 with customerId 6253
# WARNING:root:No JTL customer found for order 14651 with customerId 6254
# WARNING:root:No JTL customer found for order 14733 with customerId 6283
# WARNING:root:No JTL customer found for order 14740 with customerId 6286
# WARNING:root:No JTL customer found for order 14741 with customerId 6254
# WARNING:root:No JTL customer found for order 14746 with customerId 6254
# WARNING:root:No JTL customer found for order 14802 with customerId 6310
# WARNING:root:No JTL customer found for order 14804 with customerId 6312
# WARNING:root:No JTL customer found for order 14853 with customerId 6336
# WARNING:root:No JTL customer found for order 14977 with customerId 6393
# WARNING:root:No JTL customer found for order 14980 with customerId 6395
# WARNING:root:No JTL customer found for order 15045 with customerId 6424
# WARNING:root:No JTL customer found for order 15197 with customerId 6492
# WARNING:root:No JTL customer found for order 15206 with customerId 6496
# WARNING:root:No JTL customer found for order 15322 with customerId 6557
# WARNING:root:No JTL customer found for order 15325 with customerId 6559
# WARNING:root:No JTL customer found for order 15329 with customerId 6561
# WARNING:root:No JTL customer found for order 15451 with customerId 6614
# WARNING:root:No JTL customer found for order 15462 with customerId 6619
# WARNING:root:No JTL customer found for order 15610 with customerId 5978
# WARNING:root:No JTL customer found for order 15621 with customerId 6691
# WARNING:root:No JTL customer found for order 15949 with customerId 6850
# WARNING:root:No JTL customer found for order 16021 with customerId 6880
# WARNING:root:No JTL customer found for order 16040 with customerId 6890
# WARNING:root:No JTL customer found for order 16049 with customerId 6896
# WARNING:root:No JTL customer found for order 16113 with customerId 6923
# WARNING:root:No JTL customer found for order 16118 with customerId 6926
# WARNING:root:No JTL customer found for order 16215 with customerId 6969
# WARNING:root:No JTL customer found for order 16281 with customerId 6996
# WARNING:root:No JTL customer found for order 16307 with customerId 7010
# WARNING:root:No JTL customer found for order 16316 with customerId 7012
# WARNING:root:No JTL customer found for order 16383 with customerId 6880
# WARNING:root:No JTL customer found for order 16430 with customerId 7059
# WARNING:root:No JTL customer found for order 16441 with customerId 7064
# WARNING:root:No JTL customer found for order 16456 with customerId 7071
# WARNING:root:No JTL customer found for order 16510 with customerId 7097
# WARNING:root:No JTL customer found for order 16511 with customerId 7098
# WARNING:root:No JTL customer found for order 16539 with customerId 7106
# WARNING:root:No JTL customer found for order 16546 with customerId 7108
# WARNING:root:No JTL customer found for order 16550 with customerId 7110
# WARNING:root:No JTL customer found for order 16647 with customerId 7145
# WARNING:root:No JTL customer found for order 16698 with customerId 7064
# WARNING:root:No JTL customer found for order 16746 with customerId 7184
# WARNING:root:No JTL customer found for order 16774 with customerId 7198
# WARNING:root:No JTL customer found for order 16872 with customerId 1994
# WARNING:root:No JTL customer found for order 16895 with customerId 7064
# WARNING:root:No JTL customer found for order 16973 with customerId 7274
# WARNING:root:No JTL customer found for order 17079 with customerId 7320
# WARNING:root:No JTL customer found for order 17112 with customerId 7064
# WARNING:root:No JTL customer found for order 17168 with customerId 7362
# WARNING:root:No JTL customer found for order 17218 with customerId 7382
# WARNING:root:No JTL customer found for order 17313 with customerId 7416
# WARNING:root:No JTL customer found for order 17347 with customerId 7429
# WARNING:root:No JTL customer found for order 17421 with customerId 7459
# WARNING:root:No JTL customer found for order 17443 with customerId 5950
# WARNING:root:No JTL customer found for order 17492 with customerId 7491
# WARNING:root:No JTL customer found for order 17537 with customerId 7514
# WARNING:root:No JTL customer found for order 17582 with customerId 7538
# WARNING:root:No JTL customer found for order 17586 with customerId 7540
# WARNING:root:No JTL customer found for order 17753 with customerId 6896
# WARNING:root:No JTL customer found for order 18043 with customerId 7730
# WARNING:root:No JTL customer found for order 18069 with customerId 7738
# WARNING:root:No JTL customer found for order 18218 with customerId 7789
# WARNING:root:No JTL customer found for order 18256 with customerId 7808
# WARNING:root:No JTL customer found for order 18260 with customerId 7809
# WARNING:root:No JTL customer found for order 18267 with customerId 7810
# WARNING:root:No JTL customer found for order 18272 with customerId 7811
# WARNING:root:No JTL customer found for order 18274 with customerId 7811
# WARNING:root:No JTL customer found for order 18347 with customerId 7839
# WARNING:root:No JTL customer found for order 18355 with customerId 7843
# WARNING:root:No JTL customer found for order 18368 with customerId 7849
# WARNING:root:No JTL customer found for order 18383 with customerId 7858
# WARNING:root:No JTL customer found for order 18419 with customerId 7872
# WARNING:root:No JTL customer found for order 18421 with customerId 7873
# WARNING:root:No JTL customer found for order 18488 with customerId 7897
# WARNING:root:No JTL customer found for order 18781 with customerId 8036
# WARNING:root:No JTL customer found for order 18822 with customerId 5950
# WARNING:root:No JTL customer found for order 18881 with customerId 8080
# WARNING:root:No JTL customer found for order 18898 with customerId 8089
# WARNING:root:No JTL customer found for order 18949 with customerId 8116
# WARNING:root:No JTL customer found for order 18961 with customerId 8120
# WARNING:root:No JTL customer found for order 18966 with customerId 8122
# WARNING:root:No JTL customer found for order 19082 with customerId 8184
# WARNING:root:No JTL customer found for order 19099 with customerId 8193
# WARNING:root:No JTL customer found for order 19117 with customerId 8204
# WARNING:root:No JTL customer found for order 19199 with customerId 8237
# WARNING:root:No JTL customer found for order 19235 with customerId 8262
# WARNING:root:No JTL customer found for order 19239 with customerId 3774
# WARNING:root:No JTL customer found for order 19296 with customerId 8287
# WARNING:root:No JTL customer found for order 19297 with customerId 8288
# WARNING:root:No JTL customer found for order 19363 with customerId 8323
# WARNING:root:No JTL customer found for order 19411 with customerId 8349
# WARNING:root:No JTL customer found for order 19549 with customerId 8405
# WARNING:root:No JTL customer found for order 19561 with customerId 8411
# WARNING:root:No JTL customer found for order 19604 with customerId 8433
# WARNING:root:No JTL customer found for order 19643 with customerId 8451
# WARNING:root:No JTL customer found for order 19683 with customerId 4219
# WARNING:root:No JTL customer found for order 19766 with customerId 8495
# WARNING:root:No JTL customer found for order 19773 with customerId 8498
# WARNING:root:No JTL customer found for order 19869 with customerId 8547
# WARNING:root:No JTL customer found for order 19877 with customerId 8550
# WARNING:root:No JTL customer found for order 19932 with customerId 8575
# WARNING:root:No JTL customer found for order 20019 with customerId 8618
# WARNING:root:No JTL customer found for order 20194 with customerId 8687
# WARNING:root:No JTL customer found for order 20254 with customerId 8716
# WARNING:root:No JTL customer found for order 20283 with customerId 8728
# WARNING:root:No JTL customer found for order 20284 with customerId 8729
# WARNING:root:No JTL customer found for order 20318 with customerId 8745
# WARNING:root:No JTL customer found for order 20362 with customerId 8766
# WARNING:root:No JTL customer found for order 20419 with customerId 8798
# WARNING:root:No JTL customer found for order 20481 with customerId 8827
# WARNING:root:No JTL customer found for order 20499 with customerId 8835
# WARNING:root:No JTL customer found for order 20502 with customerId 8837
# WARNING:root:No JTL customer found for order 20514 with customerId 8843
# WARNING:root:No JTL customer found for order 20609 with customerId 8885
# WARNING:root:No JTL customer found for order 20619 with customerId 8888
# WARNING:root:No JTL customer found for order 20646 with customerId 8896
# WARNING:root:No JTL customer found for order 20672 with customerId 8909
# WARNING:root:No JTL customer found for order 20710 with customerId 8925
# WARNING:root:No JTL customer found for order 20753 with customerId 8946
# WARNING:root:No JTL customer found for order 20762 with customerId 8949
# WARNING:root:No JTL customer found for order 20927 with customerId 9023
# WARNING:root:No JTL customer found for order 21123 with customerId 9112
# WARNING:root:No JTL customer found for order 21164 with customerId 6896
# WARNING:root:No JTL customer found for order 21221 with customerId 9155
# WARNING:root:No JTL customer found for order 21362 with customerId 9215
# WARNING:root:No JTL customer found for order 21457 with customerId 9265
# WARNING:root:No JTL customer found for order 21467 with customerId 9270
# WARNING:root:No JTL customer found for order 21478 with customerId 9274
# WARNING:root:No JTL customer found for order 21529 with customerId 9298
# WARNING:root:No JTL customer found for order 21561 with customerId 9307
# WARNING:root:No JTL customer found for order 21576 with customerId 9313
# WARNING:root:No JTL customer found for order 21591 with customerId 9309
# WARNING:root:No JTL customer found for order 21623 with customerId 9328
# WARNING:root:No JTL customer found for order 21697 with customerId 9364
# WARNING:root:No JTL customer found for order 21737 with customerId 9385
# WARNING:root:No JTL customer found for order 21749 with customerId 9391
# WARNING:root:No JTL customer found for order 21806 with customerId 9419
# WARNING:root:No JTL customer found for order 21917 with customerId 9474
# WARNING:root:No JTL customer found for order 21933 with customerId 9481
# WARNING:root:No JTL customer found for order 22022 with customerId 9521
# WARNING:root:No JTL customer found for order 22034 with customerId 9526
# WARNING:root:No JTL customer found for order 22196 with customerId 9597
# WARNING:root:No JTL customer found for order 22212 with customerId 9605
# WARNING:root:No JTL customer found for order 22262 with customerId 9622
# WARNING:root:No JTL customer found for order 22285 with customerId 9630
# WARNING:root:No JTL customer found for order 22436 with customerId 9692
# WARNING:root:No JTL customer found for order 22442 with customerId 9695
# WARNING:root:No JTL customer found for order 22462 with customerId 9705
# WARNING:root:No JTL customer found for order 22488 with customerId 9721
# WARNING:root:No JTL customer found for order 22517 with customerId 9732
# WARNING:root:No JTL customer found for order 22519 with customerId 9526
# WARNING:root:No JTL customer found for order 22536 with customerId 6561
# WARNING:root:No JTL customer found for order 22558 with customerId 9754
# WARNING:root:No JTL customer found for order 22594 with customerId 9770
# WARNING:root:No JTL customer found for order 22604 with customerId 9776
# WARNING:root:No JTL customer found for order 22631 with customerId 9790
# WARNING:root:No JTL customer found for order 22714 with customerId 9829
# WARNING:root:No JTL customer found for order 22730 with customerId 9833
# WARNING:root:No JTL customer found for order 22741 with customerId 9838
# WARNING:root:No JTL customer found for order 22787 with customerId 9855
# WARNING:root:No JTL customer found for order 22838 with customerId 9875
# WARNING:root:No JTL customer found for order 22839 with customerId 9876
# WARNING:root:No JTL customer found for order 22925 with customerId 9916
# WARNING:root:No JTL customer found for order 22932 with customerId 9919
# WARNING:root:No JTL customer found for order 23040 with customerId 9969
# WARNING:root:No JTL customer found for order 23062 with customerId 9977
# WARNING:root:No JTL customer found for order 23159 with customerId 10021
# WARNING:root:No JTL customer found for order 23245 with customerId 6896
# WARNING:root:No JTL customer found for order 23443 with customerId 10156
# WARNING:root:No JTL customer found for order 23452 with customerId 10160
# WARNING:root:No JTL customer found for order 23848 with customerId 10341
# WARNING:root:No JTL customer found for order 23898 with customerId 10363
# WARNING:root:No JTL customer found for order 23976 with customerId 10396
# WARNING:root:No JTL customer found for order 23981 with customerId 10400
# WARNING:root:No JTL customer found for order 24011 with customerId 10412
# WARNING:root:No JTL customer found for order 24055 with customerId 10432
# WARNING:root:No JTL customer found for order 24081 with customerId 10446
# WARNING:root:No JTL customer found for order 24162 with customerId 10476
# WARNING:root:No JTL customer found for order 24167 with customerId 10479
# WARNING:root:No JTL customer found for order 24169 with customerId 10480
# WARNING:root:No JTL customer found for order 24175 with customerId 10482
# WARNING:root:No JTL customer found for order 24178 with customerId 10483
# WARNING:root:No JTL customer found for order 24180 with customerId 10484
# WARNING:root:No JTL customer found for order 24182 with customerId 10485
# WARNING:root:No JTL customer found for order 24186 with customerId 10486
# WARNING:root:No JTL customer found for order 24188 with customerId 10487
# WARNING:root:No JTL customer found for order 24190 with customerId 10488
# WARNING:root:No JTL customer found for order 24192 with customerId 10489
# WARNING:root:No JTL customer found for order 24195 with customerId 10490
# Conversion completed successfully! Check shopware_to_jtl.log for details.

# %%
import pandas as pd

# Load the CSV files
tlieferadresse_df = pd.read_csv('tlieferadresse.csv')
customer_df = pd.read_csv('jtl_customers_updated.csv')

# Merge the dataframes on kKunde
merged_df = pd.merge(
    tlieferadresse_df,
    customer_df[['kKunde', 'cAnrede', 'cVorname', 'cNachname', 'cTitel', 'cFirma',
                 'cZusatz', 'cStrasse', 'cHausnummer', 'cAdressZusatz', 'cPLZ',
                 'cOrt', 'cBundesland', 'cLand', 'cTel', 'cMobil', 'cFax', 'cMail']],
    on='kKunde',
    how='left',
    suffixes=('', '_customer')
)

# Update columns where customer data exists
for column in ['cAnrede', 'cVorname', 'cNachname', 'cTitel', 'cFirma', 'cZusatz',
               'cStrasse', 'cHausnummer', 'cAdressZusatz', 'cPLZ', 'cOrt',
               'cBundesland', 'cLand', 'cTel', 'cMobil', 'cFax', 'cMail']:
    merged_df[column] = merged_df[column+'_customer'].combine_first(merged_df[column])
    merged_df.drop(column+'_customer', axis=1, inplace=True)

# Save the updated dataframe
merged_df.to_csv('updated_tlieferadresse.csv', index=False)

print("Mapping completed. Updated file saved as 'updated_tlieferadresse.csv'")
# Out:
# Mapping completed. Updated file saved as 'updated_tlieferadresse.csv'

# %%
import csv

def csv_to_tlieferadresse_sql(csv_file, output_file):
    # Define all columns in tlieferadresse table with their null constraints
    # Format: (column_name, default_value_for_null)
    tlieferadresse_columns = [
        ('kLieferadresse', None),  # Primary key, must have value
        ('kKunde', None),          # Required field
        ('cAnrede', "''"),         # varchar(20), No
        ('cVorname', "''"),        # varchar(255), No
        ('cNachname', "''"),       # varchar(255), No
        ('cTitel', 'NULL'),        # varchar(64), Yes
        ('cFirma', 'NULL'),        # varchar(255), Yes
        ('cZusatz', 'NULL'),       # varchar(255), Yes
        ('cStrasse', "''"),        # varchar(255), No
        ('cHausnummer', "''"),     # varchar(32), No
        ('cAdressZusatz', 'NULL'), # varchar(255), Yes
        ('cPLZ', "''"),            # varchar(20), No
        ('cOrt', "''"),            # varchar(255), No
        ('cBundesland', "''"),     # varchar(255), No - This was the problem
        ('cLand', "''"),           # varchar(255), No
        ('cTel', 'NULL'),          # varchar(255), Yes
        ('cMobil', 'NULL'),        # varchar(255), Yes
        ('cFax', 'NULL'),          # varchar(255), Yes
        ('cMail', 'NULL')          # varchar(255), Yes
    ]

    with open(csv_file, 'r', encoding='utf-8') as csvfile, \
         open(output_file, 'w', encoding='utf-8') as sqlfile:

        reader = csv.DictReader(csvfile)

        for row in reader:
            values = []
            for column, default_null in tlieferadresse_columns:
                if column not in row or not row[column] or row[column].lower() == 'null':
                    if default_null == 'NULL':
                        values.append('NULL')
                    else:
                        values.append(default_null)
                else:
                    escaped_value = row[column].replace("'", "''")
                    values.append(f"'{escaped_value}'")

            # Create the column list with backticks
            columns = [f"`{col[0]}`" for col in tlieferadresse_columns]

            sql = f"INSERT INTO `tlieferadresse` ({', '.join(columns)}) \n"
            sql += f"VALUES ({', '.join(values)});\n"
            sqlfile.write(sql + '\n')

# Usage example:
csv_to_tlieferadresse_sql('updated_tlieferadresse.csv', 'tlieferadresse_inserts.sql')

# %%
import csv

def csv_to_sql_insert(csv_file, output_file, table_name='twarenkorb'):
    with open(csv_file, 'r', encoding='utf-8') as csvfile, \
         open(output_file, 'w', encoding='utf-8') as sqlfile:

        reader = csv.DictReader(csvfile)

        for row in reader:
            # Prepare column names and values
            columns = ['kWarenkorb', 'kKunde', 'kLieferadresse', 'kZahlungsInfo']

            # Handle NULL values for kZahlungsInfo
            zahlungsinfo = row.get('kZahlungsInfo', '0')
            if zahlungsinfo.lower() == 'null' or zahlungsinfo.strip() == '':
                zahlungsinfo = 'NULL'

            values = [
                row.get('kWarenkorb', '0'),  # Will be auto-incremented if not provided
                row.get('kKunde', '0'),
                row.get('kLieferadresse', '0'),
                zahlungsinfo
            ]

            # Build the SQL query
            sql = f"INSERT INTO {table_name} ({', '.join(columns)}) VALUES ("
            sql += ', '.join(values if values[3] == 'NULL' else [f"'{v}'" for v in values])
            sql += ");\n"

            sqlfile.write(sql)

# Example usage:
csv_to_sql_insert('warenkorb_data.csv', 'warenkorb_inserts.sql')

# %%
import csv

def generate_corrected_warenkorbpos_sql(tartikel_csv, twarenkorbpos_csv, output_sql):
    # Step 1: Build a mapping dictionary from cArtNr to kArtikel from tartikel
    artnr_to_kartikel = {}

    with open(tartikel_csv, 'r', encoding='utf-8') as artikel_file:
        artikel_reader = csv.DictReader(artikel_file, delimiter='\t')
        for row in artikel_reader:
            artnr = row.get('cArtNr', '').strip()
            kartikel = row.get('kArtikel', '').strip()
            if artnr and kartikel:
                artnr_to_kartikel[artnr] = kartikel

    # Step 2: Process twarenkorbpos and generate corrected SQL
    with open(twarenkorbpos_csv, 'r', encoding='utf-8') as warenkorbpos_file, \
         open(output_sql, 'w', encoding='utf-8') as sql_file:

        warenkorbpos_reader = csv.DictReader(warenkorbpos_file, delimiter='\t')

        for row in warenkorbpos_reader:
            # Get the original values
            original_values = row.copy()
            cArtNr = original_values.get('cArtNr', '').strip()

            # Update only the kArtikel field if we find a match
            if cArtNr in artnr_to_kartikel:
                original_values['kArtikel'] = artnr_to_kartikel[cArtNr]

            # Prepare the SQL values
            columns = []
            values = []

            for col, val in original_values.items():
                columns.append(col)
                if val == '' or val.lower() == 'null':
                    values.append('NULL')
                else:
                    values.append(f"'{val}'")

            # Generate the SQL INSERT statement
            sql = f"INSERT INTO twarenkorbpos ({', '.join(columns)}) VALUES ({', '.join(values)});\n"
            sql_file.write(sql)

# Example usage:
generate_corrected_warenkorbpos_sql(
    tartikel_csv='tartikel.csv',
    twarenkorbpos_csv='twarenkorbpos.csv',
    output_sql='corrected_warenkorbpos_inserts.sql'
)

# %%
import pandas as pd
import re

def clean_sql_value(val):
    if pd.isna(val) or val == '':
        return 'NULL'
    if isinstance(val, (int, float)):
        return str(val)
    val_str = str(val)
    # Escape special characters for SQL
    val_str = val_str.replace("\\", "\\\\").replace("'", "''")
    # Remove any remaining non-printable characters
    val_str = re.sub(r'[\x00-\x1F\x7F-\x9F]', '', val_str)
    return f"'{val_str}'"

def generate_insert_statements(csv_path, output_sql_path, batch_size=100):
    try:
        # Read CSV with encoding fallback
        encodings = ['utf-8', 'latin1', 'iso-8859-1', 'cp1252']
        df = None
        for encoding in encodings:
            try:
                df = pd.read_csv(csv_path, encoding=encoding, keep_default_na=False)
                break
            except UnicodeDecodeError:
                continue

        if df is None:
            raise ValueError("Could not read CSV file with any of the tried encodings")

        # Define default values for NOT NULL columns
        column_defaults = {
            'kWarenkorb': '0',
            'kArtikel': '0',
            'kVersandklasse': '1',
            'cLieferstatus': "''",
            'cArtNr': "''",
            'cEinheit': "''",
            'fPreisEinzelNetto': '0',
            'fPreis': '0',
            'nAnzahl': '0',
            'nPosTyp': '1',
            'cHinweis': "''",
            'cUnique': "''",
            'cResponsibility': "'core'",
            'kKonfigitem': '0',
            'kBestellpos': '0',
            'nLongestMinDelivery': '0',
            'nLongestMaxDelivery': '0'
        }

        with open(output_sql_path, 'w', encoding='utf-8') as sql_file:
            # Write header
            sql_file.write("-- AUTO-GENERATED INSERT STATEMENTS FOR `twarenkorbpos`\n")
            sql_file.write("-- Generated from: " + csv_path + "\n\n")
            sql_file.write("SET NAMES utf8mb4;\n")
            sql_file.write("SET FOREIGN_KEY_CHECKS = 0;\n\n")

            for i in range(0, len(df), batch_size):
                batch = df.iloc[i:i+batch_size]

                # Determine columns to include (exclude auto-increment if present)
                columns_to_include = [col for col in batch.columns if col != 'kWarenkorbPos']
                columns = ', '.join([f'`{col}`' for col in columns_to_include])

                value_rows = []
                for _, row in batch.iterrows():
                    values = []
                    for col in columns_to_include:
                        val = row[col]
                        if pd.isna(val) or val == '':
                            values.append(column_defaults.get(col, 'NULL'))
                        else:
                            values.append(clean_sql_value(val))
                    value_rows.append(f"({', '.join(values)})")

                insert_stmt = (
                    f"INSERT INTO `twarenkorbpos` ({columns})\n"
                    f"VALUES {', '.join(value_rows)};\n"
                )
                sql_file.write(insert_stmt + "\n")

            sql_file.write("\nSET FOREIGN_KEY_CHECKS = 1;\n")

        print(f"Success! MySQL INSERT statements generated at {output_sql_path}")
        return True

    except Exception as e:
        print(f"Error generating SQL: {str(e)}")
        return False

# Example usage
generate_insert_statements(
    csv_path='updated_output.csv',
    output_sql_path='twarenkorbpos_inserts.sql'
)
# Out:
# Success! MySQL INSERT statements generated at twarenkorbpos_inserts.sql
# True

# %%
import csv
from collections import defaultdict
import os
import sys
import pandas as pd

def read_csv_with_fallback(file_path, expected_headers=None):
    """Attempt to read CSV with multiple encoding and delimiter options"""
    encodings = ['utf-8-sig', 'utf-8', 'latin1', 'iso-8859-1', 'windows-1252']
    delimiters = ['\t', ',', ';']

    for encoding in encodings:
        for delimiter in delimiters:
            try:
                with open(file_path, 'r', encoding=encoding) as f:
                    # Peek at first line to verify headers
                    first_line = f.readline()
                    f.seek(0)

                    reader = csv.DictReader(f, delimiter=delimiter)
                    if not reader.fieldnames:
                        continue

                    if expected_headers:
                        missing_headers = set(expected_headers) - set(reader.fieldnames)
                        if missing_headers:
                            continue

                    print(f"Successfully opened {file_path} with encoding={encoding}, delimiter={repr(delimiter)}")
                    return [row for row in reader], reader.fieldnames

            except Exception as e:
                continue

    raise ValueError(f"Could not read {file_path} with any combination of encodings and delimiters")

def build_multi_column_mapping(tartikel_path):
    """Build mapping dictionary using all possible identifier columns"""
    mapping_sources = {
        'cArtNr': 'kArtikel',
        'cEAN': 'kArtikel',
        'cName': 'kArtikel',
        'cHAN': 'kArtikel'
    }

    mappings = {col: {} for col in mapping_sources.keys()}
    tartikel_data, _ = read_csv_with_fallback(tartikel_path)

    for row in tartikel_data:
        for src_col, target_col in mapping_sources.items():
            if src_col in row and target_col in row:
                key = row[src_col].strip()
                if key:
                    mappings[src_col][key] = row[target_col].strip()

    return mappings

def map_warenkorb_with_fallback(warenkorbpos_path, mappings, output_path):
    """Try multiple columns to find matches"""
    stats = {
        'total_rows': 0,
        'skipped': 0,
        'matched': defaultdict(int),
        'unmatched': 0
    }

    warenkorb_data, headers = read_csv_with_fallback(warenkorbpos_path)

    with open(output_path, 'w', encoding='utf-8', newline='') as out_file:
        writer = csv.DictWriter(out_file, fieldnames=headers, delimiter='\t')
        writer.writeheader()

        for row in warenkorb_data:
            stats['total_rows'] += 1
            matched = False

            # Try each possible mapping column
            for map_col in mappings.keys():
                if map_col in row:
                    key = row[map_col].strip()
                    if key and key in mappings[map_col]:
                        row['kArtikel'] = mappings[map_col][key]
                        stats['matched'][map_col] += 1
                        matched = True
                        break

            if not matched:
                stats['unmatched'] += 1
                if all(col not in row for col in mappings.keys()):
                    stats['skipped'] += 1

            writer.writerow(row)

    return stats

def generate_diagnostic_report(input_path):
    """Generate detailed report about CSV structure"""
    report = []

    try:
        df = pd.read_csv(input_path, delimiter='\t', encoding='latin1', nrows=1000)
        report.append(f"\nDiagnostic Report for {input_path}")
        report.append(f"Total rows: {len(df)}")
        report.append(f"Columns: {list(df.columns)}")

        report.append("\nColumn Analysis:")
        for col in df.columns:
            non_empty = df[col].notna().sum()
            unique = df[col].nunique()
            sample = df[col].dropna().sample(min(5, len(df))) if non_empty > 0 else []
            report.append(
                f"{col}: {non_empty} non-empty, {unique} unique values\n"
                f"Sample: {list(sample)}"
            )

    except Exception as e:
        report.append(f"Error generating diagnostic: {str(e)}")

    return "\n".join(report)

def main():
    # Configuration
    input_files = {
        'tartikel_path': 'tartikel.csv',
        'warenkorbpos_path': 'twarenkorbpos.csv'
    }
    output_files = {
        'output_path': 'mapped_warenkorbpos_final.csv',
        'sql_path': 'warenkorbpos_inserts_final.sql',
        'report_path': 'diagnostic_report.txt'
    }

    # Verify files
    for path in input_files.values():
        if not os.path.exists(path):
            print(f"Error: Input file {path} not found!")
            sys.exit(1)

    # Generate diagnostic report
    with open(output_files['report_path'], 'w') as report_file:
        report_file.write(generate_diagnostic_report(input_files['warenkorbpos_path']))
        report_file.write("\n\n")
        report_file.write(generate_diagnostic_report(input_files['tartikel_path']))

    print("Starting mapping process...")

    # Build comprehensive mappings
    mappings = build_multi_column_mapping(input_files['tartikel_path'])

    # Process with fallback matching
    stats = map_warenkorb_with_fallback(
        input_files['warenkorbpos_path'],
        mappings,
        output_files['output_path']
    )

    # Print results
    print("\n=== Mapping Results ===")
    print(f"Total rows processed: {stats['total_rows']}")
    print(f"Skipped (no matching columns): {stats['skipped']}")
    print(f"Matched: {sum(stats['matched'].values())}")
    for col, count in stats['matched'].items():
        print(f"  - By {col}: {count}")
    print(f"Unmatched (columns found but no match): {stats['unmatched']}")

    # Generate SQL
    print("\nGenerating SQL...")
    generate_sql(
        csv_path=output_files['output_path'],
        sql_path=output_files['sql_path']
    )

    print("\nProcessing complete!")
    print(f"Diagnostic report saved to {output_files['report_path']}")

def generate_sql(csv_path, sql_path, table_name='twarenkorbpos'):
    """Generate SQL INSERT statements"""
    try:
        with open(csv_path, 'r', encoding='utf-8') as csv_file:
            delimiter = '\t' if '\t' in csv_file.readline() else ','
            csv_file.seek(0)
            reader = csv.DictReader(csv_file, delimiter=delimiter)

            with open(sql_path, 'w', encoding='utf-8') as sql_file:
                for row in reader:
                    columns = []
                    values = []

                    for col, val in row.items():
                        columns.append(col)
                        if not val or val.lower() == 'null':
                            values.append('NULL')
                        else:
                            val = str(val).replace("'", "''")
                            values.append(f"'{val}'")

                    sql = f"INSERT INTO {table_name} ({', '.join(columns)}) VALUES ({', '.join(values)});\n"
                    sql_file.write(sql)

        print(f"SQL file generated at {sql_path}")
    except Exception as e:
        print(f"Error generating SQL: {str(e)}")
        sys.exit(1)

if __name__ == "__main__":
    main()
# Out:
# Starting mapping process...
# Successfully opened tartikel.csv with encoding=utf-8-sig, delimiter='\t'
# Successfully opened twarenkorbpos.csv with encoding=latin1, delimiter='\t'
#
# === Mapping Results ===
# Total rows processed: 51744
# Skipped (no matching columns): 51744
# Matched: 0
# Unmatched (columns found but no match): 51744
#
# Generating SQL...
# SQL file generated at warenkorbpos_inserts_final.sql
#
# Processing complete!
# Diagnostic report saved to diagnostic_report.txt

# %%
import pandas as pd
from datetime import datetime
import re

def clean_sql_value(val, col_type='string'):
    """Clean and format values for SQL insertion with type-specific handling"""
    if pd.isna(val) or val == '':
        return 'NULL'

    try:
        if col_type == 'datetime':
            dt = pd.to_datetime(val)
            return f"'{dt.strftime('%Y-%m-%d %H:%M:%S')}'"
        elif col_type == 'int':
            return str(int(float(val)))
        elif col_type == 'float':
            return str(float(val))
        else:  # string
            val_str = str(val)
            val_str = val_str.replace("\\", "\\\\").replace("'", "''")
            val_str = re.sub(r'[\x00-\x1F\x7F-\x9F]', '', val_str)  # Remove non-printables
            return f"'{val_str}'"
    except:
        return 'NULL'

def generate_twarenkorbpers_inserts(csv_path, output_sql_path, batch_size=100):
    try:
        # Read CSV with encoding fallback and explicit dtype handling
        encodings = ['utf-8', 'latin1', 'iso-8859-1', 'cp1252']
        df = None
        for encoding in encodings:
            try:
                df = pd.read_csv(
                    csv_path,
                    encoding=encoding,
                    keep_default_na=False,
                    dtype={'kKunde': 'Int64', 'kWarenkorbPers': 'Int64'},
                    parse_dates=['dErstellt'],
                    dayfirst=True  # Important for European date formats
                )
                break
            except UnicodeDecodeError:
                continue

        if df is None:
            raise ValueError("Could not read CSV file with any of the tried encodings")

        # Column type mapping for proper SQL formatting
        column_types = {
            'kWarenkorbPers': 'int',
            'kKunde': 'int',
            'dErstellt': 'datetime'
        }

        # Add kWarenkorbPers column starting from 2 if it doesn't exist
        if 'kWarenkorbPers' not in df.columns:
            df['kWarenkorbPers'] = range(2, len(df) + 2)
        else:
            # Ensure existing values start from 2
            min_val = df['kWarenkorbPers'].min()
            if pd.isna(min_val) or min_val < 2:
                df['kWarenkorbPers'] = range(2, len(df) + 2)

        with open(output_sql_path, 'w', encoding='utf-8') as sql_file:
            # Write SQL header with MariaDB/MySQL compatibility settings
            sql_file.write("/*!40101 SET @OLD_CHARACTER_SET_CLIENT=@@CHARACTER_SET_CLIENT */;\n")
            sql_file.write("/*!40101 SET @OLD_CHARACTER_SET_RESULTS=@@CHARACTER_SET_RESULTS */;\n")
            sql_file.write("/*!40101 SET @OLD_COLLATION_CONNECTION=@@COLLATION_CONNECTION */;\n")
            sql_file.write("/*!40101 SET NAMES utf8mb4 */;\n")
            sql_file.write("/*!40014 SET @OLD_FOREIGN_KEY_CHECKS=@@FOREIGN_KEY_CHECKS, FOREIGN_KEY_CHECKS=0 */;\n")
            sql_file.write("/*!40101 SET @OLD_SQL_MODE=@@SQL_MODE, SQL_MODE='NO_AUTO_VALUE_ON_ZERO' */;\n\n")

            sql_file.write(f"-- AUTO-GENERATED INSERT STATEMENTS FOR `twarenkorbpers`\n")
            sql_file.write(f"-- Generated at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
            sql_file.write(f"-- Source: {csv_path}\n\n")

            # Disable auto-increment temporarily to insert specific values
            sql_file.write("SET @OLD_AUTOCOMMIT=@@AUTOCOMMIT, AUTOCOMMIT=0;\n")
            sql_file.write("SET @OLD_UNIQUE_CHECKS=@@UNIQUE_CHECKS, UNIQUE_CHECKS=0;\n\n")

            for i in range(0, len(df), batch_size):
                batch = df.iloc[i:i+batch_size]

                # Include all columns including kWarenkorbPers
                columns = ', '.join([f'`{col}`' for col in batch.columns])

                value_rows = []
                for idx, (_, row) in enumerate(batch.iterrows(), start=2+i):
                    values = []
                    for col in batch.columns:
                        val = row[col]
                        col_type = column_types.get(col, 'string')

                        # Special handling for kWarenkorbPers to ensure it starts from 2
                        if col == 'kWarenkorbPers':
                            values.append(str(idx))
                        else:
                            values.append(clean_sql_value(val, col_type))

                    value_rows.append(f"({', '.join(values)})")

                # Generate INSERT with explicit values
                insert_stmt = (
                    f"INSERT INTO `twarenkorbpers` ({columns}) VALUES\n"
                    + ",\n".join(value_rows) + ";\n\n"
                )
                sql_file.write(insert_stmt)

            # Restore settings
            sql_file.write("\nSET UNIQUE_CHECKS=@OLD_UNIQUE_CHECKS;\n")
            sql_file.write("SET AUTOCOMMIT=@OLD_AUTOCOMMIT;\n")
            sql_file.write("/*!40101 SET SQL_MODE=@OLD_SQL_MODE */;\n")
            sql_file.write("/*!40014 SET FOREIGN_KEY_CHECKS=@OLD_FOREIGN_KEY_CHECKS */;\n")
            sql_file.write("/*!40101 SET CHARACTER_SET_CLIENT=@OLD_CHARACTER_SET_CLIENT */;\n")
            sql_file.write("/*!40101 SET CHARACTER_SET_RESULTS=@OLD_CHARACTER_SET_RESULTS */;\n")
            sql_file.write("/*!40101 SET COLLATION_CONNECTION=@OLD_COLLATION_CONNECTION */;\n")

        print(f"Success! MySQL/MariaDB INSERT statements generated at {output_sql_path}")
        return True

    except Exception as e:
        print(f"Error generating SQL: {str(e)}")
        return False

# Example usage
generate_twarenkorbpers_inserts(
    csv_path='jtl_orders_twarenkorbpers.csv',
    output_sql_path='twarenkorbpers_inserts.sql'
)
# Out:
# Success! MySQL/MariaDB INSERT statements generated at twarenkorbpers_inserts.sql
# True
